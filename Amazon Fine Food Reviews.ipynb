# %% [markdown]
# # Amazon Fine Food Reviews Sentiment Analysis with Recurrent Neural Network

# %%
import pandas as pd
import numpy as np
from collections import namedtuple
import tensorflow as tf
from string import punctuation
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.metrics import roc_curve, auc, classification_report

sns.set(color_codes=True)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Project Overview
#
# With the emergence of both social media and online reviews, sentiment analysis became an important area of research in Machine Learning. Sentiment analysis can help improve products, marketing, [clinical medicine](https://www.ncbi.nlm.nih.gov/pubmed/25982909) or even how cities  [deliver services](http://thegovlab.org/smart-cities-smart-citizens/). Sentiment analysis is a very interesting challenge to work on because the computer needs to interact with human language (natural language processing) and be able to identify and extract subjective information.
#
# Several algorithms like Naive Bayes, Support Vector Machine and Maximum Entropy are commonly used for sentiment analysis. However with the recent development of [recurrent neural networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/), Deep Learning has started to outperform all the other methods due to its ability to build a representation of whole sentences based on the sentence structure. Several amazing research papers have already been published on this topic by Stanford (e.g. [Sentiment Analysis](https://nlp.stanford.edu/sentiment/])) and OpenAi (e.g. [unsupervised sentiment neuron](https://blog.openai.com/unsupervised-sentiment-neuron/#sentimentneuron])).
#
# For this project, we will perform sentiment analysis on the [Amazon Fine Food Review](https://www.kaggle.com/snap/amazon-fine-food-reviews) dataset from Kaggle.
#
# ### Problem Statement
#
# This is a supervised learning problem where we need to predict the positive or negative target variable for each review. The goal will be to maximize the accuracy of this classification.  We will train our model on a dataset containing thousands of reviews presented as unstructured text. Each review will be labeled as positive or negative.
#
# To solve this problem we will perform the following tasks:
#   1. Preprocess the data.
#   2. Train and tune the hyperparameters of the recurrent neural network.
#   3. Test the accuracy of the model on the testing set.

# %% [markdown]
# ## Exploratory Data Analysis
#
# Before building our recurrent neural network we will start by exploring our dataset. You can download the [Reviews.csv](https://www.kaggle.com/snap/amazon-fine-food-reviews) file from Kaggle. Let's start by loading the data.

# %%
data = pd.read_csv("input/Reviews.csv")

# %% [markdown]
# How many reviews are included in this dataset?

# %%
print("Number of reviews:",len(data))
# Out:
# Number of reviews: 568454

# %% [markdown]
# The dataset contains 568,454 food reviews Amazon users left from October 1999 to October 2012.

# %% [markdown]
# What are the fields provided in the Amazon fine food reviews dataset?

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# The review for a specific product by a specific user is stored in the Text column. The Text column consists of an unstructured text. In addition to the Text feature representing the review, we can identify the product using the ProductId feature, the Amazon user with the UserID feature, the date the review was posted by the Time column, and a brief summary of the review with the Summary variable. Additionally, HelpfulnessNumerator and HelpfulnessDenominator, two variables representing how helpful a review is, are also provided in the review.
#
# More importantly, for each review, we have a “Score” variable representing a rating from 1 to 5 (1 is a poor review, and 5 is an excellent review).

# %% [markdown]
# ### Sentiment Score

# %% [markdown]
# Here is the distribution of the score:

# %%
ax = plt.axes()
sns.countplot(data.Score,ax=ax)
ax.set_title('Score Distribution')
plt.show()

# %%
print("Average Score: ",np.mean(data.Score))
print("Median Score: ",np.median(data.Score))
# Out:
# Average Score:  4.18319864052
# Median Score:  5.0

# %% [markdown]
# As we can observe, the majority of Scores are equal to 4 and 5, and with an average score of 4.18. Because of the distribution is very skewed to the left, we will make a binary prediction. We can consider a negative review will have a Score between 1 and 3, and a positive review will have a Score equal to 4 or 5.

# %%
data.ix[data.Score>3,'Sentiment']="POSITIVE"
data.ix[data.Score<=3,'Sentiment']="NEGATIVE"

# %% [markdown]
# After creating a new variable named Sentiment that is set to NEGATIVE when the Score is between 1 and 3, and POSITIVE when the Score is equal to 4 or 5, we get this new distribution:

# %%
ax = plt.axes()
sns.countplot(data.Sentiment,ax=ax)
ax.set_title('Sentiment Positive vs Negative Distribution')
plt.show()

# %%
print("Proportion of positive review:", len(data[data.Sentiment=="POSITIVE"])/len(data))
print("Proportion of positive review:",len(data[data.Sentiment=="NEGATIVE"])/len(data))
# Out:
# Proportion of positive review: 0.7806735461444549
# Proportion of positive review: 0.21932645385554503

# %% [markdown]
# With this new classification, 78% of the fine food reviews are considered as positive and 22% of them are considered as negative.

# %% [markdown]
# As we only need the Text field as an input for our model and the Sentiment (positive or negative) as an ouput, we will store this information in a reviews and sentiment variables.

# %%
reviews = data.Text.values
labels = data.Sentiment.values

# %% [markdown]
# ### Text Reviews

# %% [markdown]
# Now let's explore our input variable "text" which contains the review of the product.

# %%
def pretty_print_review_and_label(i):
    if data.Sentiment[i]=="POSITIVE":
        print("POSITIVE" + "\t" + reviews[i][:90] + "...")
    else:
        print("NEGATIVE" + "\t " + reviews[i][:90] + "...")

# %%
pretty_print_review_and_label(1)
pretty_print_review_and_label(4)
pretty_print_review_and_label(5)
pretty_print_review_and_label(50)
# Out:
# NEGATIVE	 Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized un...
# POSITIVE	Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was v...
# POSITIVE	I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoya...
# NEGATIVE	 This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go....

# %% [markdown]
# The input variable is an unstructured text. By just looking at the first 90 characters, we can quickly have an idea of whether the review is positive or negative. For the negative reviews, we have negative expressions such as "not good", or "don't like it." These negative expressions can also be more nuanced depending on the context, such as "were actually small sized." For positive reviews, users use positive expression such as "Great taffy", "great price", "wide assortment", "yummy taffy", "very enjoyable," etc.
#
# It's important to note that the text is unstructured, and we will have to do some pre-processing to remove punctuations, transform upper-case to lower case, etc.

# %% [markdown]
# ### Exploratory Visualization
#
# A common approach to distinguish positive from negative reviews is to look at the frequency of the words. We can imagine that certain words, such as "excellent" or "very tasty," tend to occur more often in positive reviews than negative reviews. Let's see if we can validate this theory.

# %%
positive_reviews = [reviews[i] for i in range(len(reviews)) if labels[i]=="POSITIVE"]
negative_reviews = [reviews[i] for i in range(len(reviews)) if labels[i]=="NEGATIVE"]

# %%
from collections import Counter

cnt_positve = Counter()

for row in positive_reviews:
    cnt_positve.update(row.split(" "))
print("Vocabulary size for positve reviews:", len(cnt_positve.keys()))

cnt_negative = Counter()

for row in negative_reviews:
    cnt_negative.update(row.split(" "))
print("Vocabulary size for positve reviews:", len(cnt_negative.keys()))

cnt_total = Counter()

for row in reviews:
    cnt_total.update(row.split(" "))
# Out:
# Vocabulary size for positve reviews: 480349
# Vocabulary size for positve reviews: 239355

# %%
pos_neg_ratio = Counter()
vocab_pos_neg = (set(cnt_positve.keys())).intersection(set(cnt_negative.keys()))
for word in vocab_pos_neg:
    if cnt_total[word]>100:
        ratio = cnt_positve[word]/float(cnt_negative[word]+1)
        if ratio>1:
            pos_neg_ratio[word] = np.log(ratio)
        else:
            pos_neg_ratio[word] = -np.log(1/(ratio+0.01))

# %% [markdown]
# After calculating the ratio between the frequency count in the positive review divided by the frequency count in the negative review for each word, here are the results:
#
#
# When the ratio is high (greater than 1), it means than the words tend to occur more often in positive reviews than in negative reviews.

# %%
pos_neg_ratio .most_common()[:30]
# Out:
# [('/>Highly', 5.7914880550753063),
#  ('anytime.', 5.1474944768134527),
#  ('soothing.', 4.9126548857360524),
#  ('addictive!', 4.8978397999509111),
#  ('Enjoy.', 4.8402423081675749),
#  ('/>Magnesium', 4.7214706416842516),
#  ('/>Almonds', 4.7095302013123339),
#  ('versatile.', 4.6443908991413725),
#  ('Rich,', 4.6347289882296359),
#  ('organs.', 4.5325994931532563),
#  ('hooked.', 4.516338972281476),
#  ('Delicious!', 4.496630017412885),
#  ('diet?', 4.4485163759427149),
#  ('/>1st', 4.4426512564903167),
#  ('Cakesters', 4.3820266346738812),
#  ('Booda', 4.377851263263401),
#  ('far!', 4.3694478524670215),
#  ('*****<br', 4.3652195163575005),
#  ('Favorites"', 4.3372907408324899),
#  ('Sciences', 4.3372907408324899),
#  ('synthesis.', 4.3372907408324899),
#  ('Highly', 4.3313052590894525),
#  ('Chili<br', 4.3174881135363101),
#  ('addicted!', 4.3107991253855138),
#  ('plus!', 4.3040650932041702),
#  ('favorites!', 4.3040650932041702),
#  ('Delicious.', 4.2986450257348308),
#  ('Yummy!', 4.295015257684252),
#  ('disappoint!', 4.2835865618606288),
#  ('recommended!', 4.282206299391671)]

# %%
positive_dict = {}
for word, cnt in pos_neg_ratio.items():
    if (cnt>1):
        positive_dict[word] = cnt

wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=positive_dict)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
ax = plt.axes()
ax.set_title('Word Cloud with the Highest Positive/Negative Ratio')
plt.show()

# %% [markdown]
# In the word cloud above, some words that stand out are "highly", "addictive", "soothing", and "enjoy," which have a positive meaning. Certain ingredients or products are also highlighted like "chili", "magnesium", "almonds," etc. These word are neutral, but probably appear often in positive reviews as a result of Amazon's inventory; Amazon likely selects to distribute products, like almonds or chili, that meet or surpass users' expectations.

# %% [markdown]
# Let's look now at the words that tend to occur more often in negative reviews than in positive reviews.

# %%
list(reversed(pos_neg_ratio.most_common()))[0:30]
# Out:
# [('FREAKS', -4.2030108660144263),
#  ('factory)', -4.2013648292982912),
#  ('judgment,', -4.2013648292982912),
#  ('mistakes.<br', -3.9145136667405982),
#  ('howling,', -3.912023005428146),
#  ('NO<br', -3.328075116833193),
#  ('sad.<br', -3.2481462071683138),
#  ('Lives,', -3.2188758248682006),
#  ('Reducing', -3.2188758248682006),
#  ('slaughterhouse', -3.1778728512505374),
#  ('ANYMORE.', -3.1424854222041994),
#  ('(good,', -3.1088233633266724),
#  ('mischief.', -3.1010927892118172),
#  ('blue)', -2.9045009573244873),
#  ('disappointment!', -2.8650573056222033),
#  ('crying,', -2.7623992656292384),
#  ('5/8', -2.7459515879050338),
#  ('"healthy,"', -2.7375866155346618),
#  ('trashing', -2.6486357670125487),
#  ('deliberately', -2.5174652359649476),
#  ('returnable', -2.4899191916115448),
#  ('disorder.', -2.4825564724430467),
#  ('Halo,', -2.4427317247372873),
#  ('deceptive', -2.4079456086518718),
#  ('Horrible', -2.3990070016510612),
#  ('Buyer', -2.3765230838453015),
#  ('twenty-five', -2.3421120731379679),
#  ('horrible!', -2.2335922215070942),
#  ('stupid,', -2.2276837848209281),
#  ('chubby.', -2.1673760040118015)]

# %%
negative_dict = {}
for word, cnt in pos_neg_ratio.items():
    if (cnt<1) & (cnt>0):
        negative_dict[word] = -np.log(cnt)

wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=negative_dict)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
ax = plt.axes()
ax.set_title('Word Cloud with the Lowest Positive/Negative Ratio')
plt.show()

# %% [markdown]
# There are several negative words, such as "strange", "failed", "fooled", and "choke". However it's more difficult to understand why certain words like "wellness," "feet," and "buyer" appear more often in negative reviews.

# %% [markdown]
# ## Algorithms and Techniques
#
# In order to predict if a review is positive or negative we will use a recurrent neural network. Most of the methods for sentiment analysis look at each word individually, attribute positive points for positive words and negative points for negative words, and then total the points. This is the lexicon approach. However the problem with this method is that it ignores the sequence of the words, which can lead to the loss of important information. The RNN approach can understand subtleties because it doesn’t analyze text at face value. It creates abstract representations of what it learned.
#
# We will use Long Short Term Memory Networks (LSTM), which is a special case of RNN. The main advantage of LSTM is that it can memorize information. When there's too large of a gap between two pieces of information, RNN is unable to learn to connect information. To learn more about LSTM, you can read this excellent  [article](http://colah.github.io/posts/2015-08-Understanding-LSTMs/)  written by Christopher Olah.
#
# I have borrowed the diagram below from the Udacity Deep Learning Nanodegree.
#
# <p align="center">
# <img src="Report/Images/network_diagram.png" width="300" height="300" />
# </p>
#
# #### Embedding
# First we will use an embedding layer in order to represent words by a vectors. This representation is more efficient than one-hot encoding, especially in the actual context where the size of the vocabulary is more than 240,000 words.
#
# To generate these embeddings, we will use the word2vec approach, so when words have similar meanings they will be close to each other.
#
# <p align="center">
# <img src="Report/Images/word2vec.png" width="600" height="200" />
# </p>
#
# The word2vec approach is based on the assumption that similar words happen in similar context. By using this method, we are able to determine some semantic relationships, like, for example, the fact that a man and a king are male, or that a woman and a queen are female. You can learn more about embedding [here](https://www.tensorflow.org/tutorials/word2vec).
#
#
# #### Long Short Term Memory
# The next step is to pass the embedded words to the LSTM cells. In the graph, you can observe that there are connections between the first, second and third LSTM cells. In contrast to other models that assume that all the inputs are independent of each other, these connections here allow us to pass information contained in the sequence of words. One of the strengths of the LSTM cell is the ability to add or remove information to the cell state.
#
#
# #### Output: positive or negative?
# Finally, we will predict if the review is positive or negative using the sigmoid function. The advantage of the function is that it's bound between 0 and 1 and can be interpreted as a probability of success. For example, we can estimate the probability that a review is positive. At each step, we have an output. However, we only care about the final output that predicts the sentiment at the end of the sentence.
#
# #### Tuning hyperparameters
#
# For our recurrent neural network we will have to tune the following hyperparameters:
#
# Optimizer hyperparameters:
#   - Learning rate
#   - Minibatch size
#   - Number of epochs
#
# Model hyperparameters:
#   - Number of hidden layers (LSTM layers)
#   - Number of units in the LSTM cells
#   - Dropout rate

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# In order to train our model, we had to transform the reviews into the right format. We performed the following steps:

# %%
reviews = data.Text.values
labels = np.array([1 if s=="POSITIVE" else 0 for s in data.Sentiment.values])

# %% [markdown]
# First we need to remove punctuations and transform all the characters into a list of integers.

# %%
reviews_cleaned = []
for i in range(len(reviews)):
    reviews_cleaned.append(''.join([c.lower() for c in reviews[i] if c not in punctuation]))

# %%
print("Before: ",reviews[0])
print("")
print("After: ",reviews_cleaned[0])
# Out:
# Before:  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
#
# After:  i have bought several of the vitality canned dog food products and have found them all to be of good quality the product looks more like a stew than a processed meat and it smells better my labrador is finicky and she appreciates this product better than  most

# %% [markdown]
# What's the size of the vocabulary after removing punctuations and transform characters to lower case?

# %%
vocabulary = set(' '.join(reviews_cleaned).split())
print("Vocabulary size: ", len(vocabulary))
# Out:
# Vocabulary size:  240772

# %% [markdown]
# ## Noise reduction by reducing vocabulary

# %% [markdown]
# Let's create a vocabulary reduction function in case we want to reduce the vocabulary based on min frequency or polarity.

# %%
def vocabulary_reduction(reviews,min_freq=10,polarity_cut_off=0.1):
    
    pos_count = Counter()
    neg_count = Counter()
    tot_count = Counter()

    for i in range(len(reviews)):
        for word in reviews[i].split():
            tot_count[word]+=1
            if labels[i] == 1:
                pos_count[word]+=1
            else:
                neg_count[word]+=1    
    
    #Identify words with frequency greater than min_freq
    vocab_freq = []
    for word in tot_count.keys():
        if tot_count[word]>min_freq:
            vocab_freq.append(word)  
    
    #Use polarity to reduce vocab
    pos_neg_ratio = Counter()
    vocab_pos_neg = (set(pos_count.keys())).intersection(set(neg_count.keys()))
    for word in vocab_pos_neg:
        if tot_count[word]>100:
            ratio = pos_count[word]/float(neg_count[word]+1)
            if ratio>1:
                pos_neg_ratio[word] = np.log(ratio)
            else:
                pos_neg_ratio[word] = -np.log(1/(ratio+0.01)) 
    
    mean_ratio = np.mean(list(pos_neg_ratio.values()))
    
    vocab_polarity = []
    for word in pos_neg_ratio.keys():
        if (pos_neg_ratio[word]<(mean_ratio-polarity_cut_off)) or (pos_neg_ratio[word]>(mean_ratio+polarity_cut_off)):
            vocab_polarity.append(word)
     
    vocab_rm_polarity = set(pos_neg_ratio.keys()).difference(vocab_polarity)
    vocab_reduced = (set(vocab_freq)).difference(set(vocab_rm_polarity))
 
    reviews_cleaned = []
    
    for review in reviews:
        review_temp = [word for word in review.split() if word in vocab_reduced]
        reviews_cleaned.append(' '.join(review_temp))
    
    return reviews_cleaned

# %%
reviews_cleaned = vocabulary_reduction(reviews_cleaned,min_freq=0,polarity_cut_off=0)

# %% [markdown]
# Then we need to transform each review into a list of integers. First we can create a dictionary to map each word contained in vocabulary of the reviews to an integer.

# %%
# Store all the text from each review in a text variable
text = ' '.join(reviews_cleaned)

# List all the vocabulary contained in the reviews
vocabulary = set(text.split(' '))

# Map each word to an integer
vocabulary_to_int = {word:i for i,word in enumerate(vocabulary,0)}

# %% [markdown]
# Once we have the vocabulary_to_int dictionary created, we can transform each review into a list of integers using the dictionary previously created.

# %%
def reviews_to_integers(reviews):
    reviews_to_int = []
    for i in range(len(reviews)):
        to_int = [vocabulary_to_int[word] for word in reviews[i].split()]
        reviews_to_int.append(to_int)
    return reviews_to_int

reviews_to_int = reviews_to_integers(reviews_cleaned)

# %% [markdown]
# To train the RRN on the review dataset we have to create an array with 200 columns, and enough rows to fit one review per row. Then store each review consisting of integers in the array. If the number of words in the review is less than 200 words, we can pad the list with extra zeros. If the number of words in the review are more than 200 words then we can limit the review to the first 200 words.

# %%
review_lengths = [len(review) for review in reviews_to_int]
print("Shortest review:", min(review_lengths))
print("Longest revies:",max(review_lengths))
# Out:
# Shortest review: 3
# Longest revies: 3414

# %% [markdown]
# If we don't limit the review to 200 words, it will take too much time for the RRN to train. Here is the distribution of the review length:

# %%
ax = plt.axes()
sns.distplot(review_lengths)
ax.set_title("Distribution of the review lengths")
plt.plot()
# Out:
# []

# %%
pd.DataFrame(review_lengths).describe()
# Out:
#                    0
# count  568454.000000
# mean       79.913333
# std        79.017418
# min         3.000000
# 25%        33.000000
# 50%        56.000000
# 75%        97.000000
# max      3414.000000

# %% [markdown]
# The mean and the third quartile of the review length is equal to 79 and 97, respectively.  Therefore if we limit the review length to 200 words, we shouldn't lose too much information.

# %%
max_length = 200
features = np.zeros(shape=(len(reviews_to_int),max_length),dtype=int)

# %%
for i in range(len(reviews_to_int)):
    nb_words = len(reviews_to_int[i])
    features[i] = [0]*(max_length -nb_words) + reviews_to_int[i][:200]

# %% [markdown]
# ### Training, validation and split

# %% [markdown]
# In order to train our RNN model and evaluate it, it’s important to split the data into training, validation and testing datasets. We will train the model on a training set, and tune the model by validating the results on the validation dataset. Finally we will measure the ability of our model to generalize by testing our model on the testing dataset.

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=5435)

splitter = sss.split(features, labels)
train_index, validation_index = next(splitter)
test_index = validation_index[:int(len(validation_index)/2)]
validation_index = validation_index[int(len(validation_index)/2):]

train_x, train_y = features[train_index], labels[train_index]
val_x, val_y = features[test_index], labels[test_index]
test_x, test_y = features[validation_index], labels[validation_index]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(454763, 200)
# Validation set: 	(56845, 200)
# Test set: 		(56846, 200)

# %% [markdown]
# ### Build the LSTM model with Tensorflow
# The next step is to build the recurrent neural network using the popular deep learning framework, Tensorflow.
#
# To feed input, labels and keep_prob data into Tensorflow we need to first create placeholders.
# ```python
# inputs_ = tf.placeholder(tf.int32,[None, None],name='inputs_')
# labels_ = tf.placeholder(tf.int32,[None, None],name='labels_')
# keep_prob = tf.placeholder(tf.float32,name='keep_prob')
# ```
#
# Once we send the input data (the reviews) to Tensorflow, we want to transform each integer representing a word into a vector. As mentioned earlier, this method is called embedding.
#
# ```python
# embedding = tf.Variable(tf.random_normal((n_words,embed_size),-1,1),name='embedding_')
# embed = tf.nn.embedding_lookup(embedding,inputs_)
# ```
#
# Then we need to create our LSTM cells and specify the number of hidden units in the LSTM cell.
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
# ```
#
# It's always a good practice to add a Dropout layer to prevent the model from overfitting on the training set.
# ```python
# drop = tf.contrib.rnn.DropoutWrapper(lstm,output_keep_prob=keep_prob)
# ```
# By using tf.contrib.rnn.MultiRNNCell we can stack multiple LSTM layers. Usually in deep learning, the more hidden layers you have, the better the prediction will be.
# ```python
# cell = tf.contrib.rnn.MultiRNNCell([drop]*lstm_layer*)
# ```
#
# We initialize all the states to zero.
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Then we want to pass the input data through the LSTM cells. The output of each LSTM cell is carried to the next LSTM cell. This mechanism allow the recurrent neural network to memorize information.
# ```python
# outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)
# ```
#
# To get our prediction, we use a fully connected layer with a sigmoid function.
# ```python
# predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1,
#                                                 activation_fn=tf.sigmoid,
#                                                 weights_initializer=
#                                                 tf.truncated_normal_initializer(stddev=0.1))
# ```
#
# To measure the accuracy of our neural network, we need to define the cost function. For this problem, we will use the mean squared error.
# ```python
# cost = tf.losses.mean_squared_error(labels_, predictions)
# ```
# Finally, we want to minimize our cost function in order to make our network output as close as possible to the target values. For this project, we will use the Adam optimizer.
# ```python
# optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
# ```

# %%
lstm_size = 256
lstm_layers = 1
batch_size = 500
learning_rate = 0.001
embed_size = 200

# %%
def build_rnn(vocabulary_to_int,
              embed_size=embed_size,
              batch_size=batch_size,
              learning_rate=learning_rate,
              lstm_size=lstm_size,
              lstm_layers=lstm_layers):
    
    tf.reset_default_graph()
    
    n_words = len(vocabulary_to_int)
    
    with tf.name_scope('inputs'):
        inputs_ = tf.placeholder(tf.int32,[None, None],name='inputs_')
    with tf.name_scope('labels'):
        labels_ = tf.placeholder(tf.int32,[None, None],name='labels_')
    with tf.name_scope('keep_prob'):    
        keep_prob = tf.placeholder(tf.float32,name='keep_prob')
        
    with tf.name_scope('embedding'):
        embedding = tf.Variable(tf.random_normal((n_words,embed_size),-1,1),name='embedding_')
        embed = tf.nn.embedding_lookup(embedding,inputs_)
        
    with tf.name_scope("RNN_cells"):
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)

        # Add dropout to the cell
        drop = tf.contrib.rnn.DropoutWrapper(lstm,output_keep_prob=keep_prob)

        # Stack up multiple LSTM layers, for deep learning
        cell = tf.contrib.rnn.MultiRNNCell([drop]*lstm_layers)
        
        with tf.name_scope("RNN_init_state"):
            # Getting an initial state of all zeros
            initial_state = cell.zero_state(batch_size, tf.float32)
    
    with tf.name_scope("RNN_forward"):
        outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)
        
    with tf.name_scope('predictions'):
        predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, 
                                                        activation_fn=tf.sigmoid,
                                                        weights_initializer=
                                                        tf.truncated_normal_initializer(stddev=0.1))   
    with tf.name_scope('cost'):
        cost = tf.losses.mean_squared_error(labels_, predictions)
        tf.summary.scalar('cost', cost)
    
    with tf.name_scope('train'):
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    
    with tf.name_scope('accuracy'):
        correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    
    merged = tf.summary.merge_all()
    
    # Export the nodes 
    export_nodes = ['inputs_', 'labels_','initial_state', 'final_state',
                    'keep_prob', 'cell', 'cost', 'predictions', 'optimizer',
                    'accuracy','merged']
    
    Graph = namedtuple('Graph', export_nodes)
    
    local_dict = locals()
    graph = Graph(*[local_dict[each] for each in export_nodes])
    
    return graph

# %% [markdown]
# In the code below, we are using tf.summary.FileWriter in order to be able to visualize in Tensorboard if our model has been built correctly.

# %%
graph = build_rnn(vocabulary_to_int,
              embed_size=embed_size,
              batch_size=batch_size,
              learning_rate=learning_rate,
              lstm_size=lstm_size,
              lstm_layers=lstm_layers)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    file_writer = tf.summary.FileWriter('output/logs/1', sess.graph)

# %% [markdown]
# To train our model, we use the stochastic gradient descent approach. This method consists of calculating an estimate of the cost function on small batches of the dataset. This approach is more scalable than a traditional gradient descent.

# %%
def get_batches(x, y, batch_size=100):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %%
epochs = 5

def train(model, epoch,train_writer,test_writer):
    
    saver = tf.train.Saver()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
    
        iteration = 1
        for e in range(epochs):
            state = sess.run(model.initial_state)

            for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
                feed = {model.inputs_: x,
                        model.labels_: y[:, None],
                        model.keep_prob: 0.5,
                        model.initial_state: state}
                summary,loss, state, _ = sess.run([model.merged,model.cost, 
                                                   model.final_state, 
                                                   model.optimizer], feed_dict=feed)

                if iteration%5==0:
                    print("Epoch: {}/{}".format(e, epochs),
                          "Iteration: {}".format(iteration),
                          "Train loss: {:.3f}".format(loss))

                train_writer.add_summary(summary, iteration)

                if iteration%25==0:
                    val_acc = []
                    val_state = sess.run(model.cell.zero_state(batch_size, tf.float32))
                    for x, y in get_batches(val_x, val_y, batch_size):
                        feed = {model.inputs_: x,
                                model.labels_: y[:, None],
                                model.keep_prob: 1,
                                model.initial_state: val_state}
                        summary, batch_acc, val_state = sess.run([model.merged,model.accuracy, 
                                                         model.final_state], feed_dict=feed)
                        val_acc.append(batch_acc)

                    test_writer.add_summary(summary,iteration)
                    print("Val acc: {:.3f}".format(np.mean(val_acc)))

                iteration +=1
        saver.save(sess, "output/checkpoints/sentiment.ckpt")

# %% [markdown]
# Then we can train our model on a single combination of parameters or we can test multiple combinations of hyperparameters.

# %%
lstm_size_options = [256]
lstm_layers_options = [1]
learning_rate_options = [0.001]

#lstm_size_options = [128,256,512]
#lstm_layers_options = [1, 2]
#learning_rate_options = [0.002, 0.001]

# %%
for lstm_size in lstm_size_options:
    for lstm_layers in lstm_layers_options:
        for learning_rate in learning_rate_options:
            log_string_train = 'output/logs/2/train/lr={},rl={},ru={}'.format(learning_rate, lstm_layers, lstm_size)
            log_string_test = 'output/logs/2/test/lr={},rl={},ru={}'.format(learning_rate, lstm_layers, lstm_size)
            train_writer = tf.summary.FileWriter(log_string_train)
            test_writer = tf.summary.FileWriter(log_string_test)
            
            print("lstm size: {}".format(lstm_size),
                    "nb layers : {}".format(lstm_layers),
                    "learn rate : {:.3f}".format(learning_rate))
            
            model = build_rnn(vocabulary_to_int,
                      embed_size=embed_size,
                      batch_size=batch_size,
                      learning_rate=learning_rate,
                      lstm_size=lstm_size,
                      lstm_layers=lstm_layers)

            train(model, epochs, train_writer,test_writer)
# Out:
# lstm size: 256 nb layers : 1 learn rate : 0.001
# Epoch: 0/5 Iteration: 5 Train loss: 0.202
# Epoch: 0/5 Iteration: 10 Train loss: 0.240
# Epoch: 0/5 Iteration: 15 Train loss: 0.265
# Epoch: 0/5 Iteration: 20 Train loss: 0.230
# Epoch: 0/5 Iteration: 25 Train loss: 0.193
# Val acc: 0.780
# Epoch: 0/5 Iteration: 30 Train loss: 0.178
# Epoch: 0/5 Iteration: 35 Train loss: 0.184
# Epoch: 0/5 Iteration: 40 Train loss: 0.183
# Epoch: 0/5 Iteration: 45 Train loss: 0.169
# Epoch: 0/5 Iteration: 50 Train loss: 0.175
# Val acc: 0.780
# Epoch: 0/5 Iteration: 55 Train loss: 0.190
# Epoch: 0/5 Iteration: 60 Train loss: 0.176
# Epoch: 0/5 Iteration: 65 Train loss: 0.185
# Epoch: 0/5 Iteration: 70 Train loss: 0.164
# Epoch: 0/5 Iteration: 75 Train loss: 0.171
# Val acc: 0.780
# Epoch: 0/5 Iteration: 80 Train loss: 0.175
# Epoch: 0/5 Iteration: 85 Train loss: 0.180
# Epoch: 0/5 Iteration: 90 Train loss: 0.185
# Epoch: 0/5 Iteration: 95 Train loss: 0.176
# Epoch: 0/5 Iteration: 100 Train loss: 0.162
# Val acc: 0.780
# Epoch: 0/5 Iteration: 105 Train loss: 0.161
# Epoch: 0/5 Iteration: 110 Train loss: 0.157
# Epoch: 0/5 Iteration: 115 Train loss: 0.165
# Epoch: 0/5 Iteration: 120 Train loss: 0.168
# Epoch: 0/5 Iteration: 125 Train loss: 0.171
# Val acc: 0.780
# Epoch: 0/5 Iteration: 130 Train loss: 0.165
# Epoch: 0/5 Iteration: 135 Train loss: 0.179
# Epoch: 0/5 Iteration: 140 Train loss: 0.159
# Epoch: 0/5 Iteration: 145 Train loss: 0.179
# Epoch: 0/5 Iteration: 150 Train loss: 0.160
# Val acc: 0.780
# Epoch: 0/5 Iteration: 155 Train loss: 0.187
# Epoch: 0/5 Iteration: 160 Train loss: 0.161
# Epoch: 0/5 Iteration: 165 Train loss: 0.145
# Epoch: 0/5 Iteration: 170 Train loss: 0.171
# Epoch: 0/5 Iteration: 175 Train loss: 0.158
# Val acc: 0.781
# Epoch: 0/5 Iteration: 180 Train loss: 0.164
# Epoch: 0/5 Iteration: 185 Train loss: 0.164
# Epoch: 0/5 Iteration: 190 Train loss: 0.168
# Epoch: 0/5 Iteration: 195 Train loss: 0.146
# Epoch: 0/5 Iteration: 200 Train loss: 0.136
# Val acc: 0.781
# Epoch: 0/5 Iteration: 205 Train loss: 0.150
# Epoch: 0/5 Iteration: 210 Train loss: 0.166
# Epoch: 0/5 Iteration: 215 Train loss: 0.157
# Epoch: 0/5 Iteration: 220 Train loss: 0.150
# Epoch: 0/5 Iteration: 225 Train loss: 0.152
# Val acc: 0.795
# Epoch: 0/5 Iteration: 230 Train loss: 0.133
# Epoch: 0/5 Iteration: 235 Train loss: 0.148
# Epoch: 0/5 Iteration: 240 Train loss: 0.122
# Epoch: 0/5 Iteration: 245 Train loss: 0.151
# Epoch: 0/5 Iteration: 250 Train loss: 0.132
# Val acc: 0.824
# Epoch: 0/5 Iteration: 255 Train loss: 0.133
# Epoch: 0/5 Iteration: 260 Train loss: 0.133
# Epoch: 0/5 Iteration: 265 Train loss: 0.133
# Epoch: 0/5 Iteration: 270 Train loss: 0.137
# Epoch: 0/5 Iteration: 275 Train loss: 0.145
# Val acc: 0.827
# Epoch: 0/5 Iteration: 280 Train loss: 0.110
# Epoch: 0/5 Iteration: 285 Train loss: 0.153
# Epoch: 0/5 Iteration: 290 Train loss: 0.135
# Epoch: 0/5 Iteration: 295 Train loss: 0.128
# Epoch: 0/5 Iteration: 300 Train loss: 0.100
# Val acc: 0.839
# Epoch: 0/5 Iteration: 305 Train loss: 0.106
# Epoch: 0/5 Iteration: 310 Train loss: 0.124
# Epoch: 0/5 Iteration: 315 Train loss: 0.117
# Epoch: 0/5 Iteration: 320 Train loss: 0.149
# Epoch: 0/5 Iteration: 325 Train loss: 0.113
# Val acc: 0.846
# Epoch: 0/5 Iteration: 330 Train loss: 0.110
# Epoch: 0/5 Iteration: 335 Train loss: 0.112
# Epoch: 0/5 Iteration: 340 Train loss: 0.124
# Epoch: 0/5 Iteration: 345 Train loss: 0.097
# Epoch: 0/5 Iteration: 350 Train loss: 0.103
# Val acc: 0.854
# Epoch: 0/5 Iteration: 355 Train loss: 0.116
# Epoch: 0/5 Iteration: 360 Train loss: 0.105
# Epoch: 0/5 Iteration: 365 Train loss: 0.106
# Epoch: 0/5 Iteration: 370 Train loss: 0.112
# Epoch: 0/5 Iteration: 375 Train loss: 0.098
# Val acc: 0.847
# Epoch: 0/5 Iteration: 380 Train loss: 0.106
# Epoch: 0/5 Iteration: 385 Train loss: 0.106
# Epoch: 0/5 Iteration: 390 Train loss: 0.102
# Epoch: 0/5 Iteration: 395 Train loss: 0.124
# Epoch: 0/5 Iteration: 400 Train loss: 0.110
# Val acc: 0.864
# Epoch: 0/5 Iteration: 405 Train loss: 0.106
# Epoch: 0/5 Iteration: 410 Train loss: 0.097
# Epoch: 0/5 Iteration: 415 Train loss: 0.120
# Epoch: 0/5 Iteration: 420 Train loss: 0.101
# Epoch: 0/5 Iteration: 425 Train loss: 0.093
# Val acc: 0.866
# Epoch: 0/5 Iteration: 430 Train loss: 0.109
# Epoch: 0/5 Iteration: 435 Train loss: 0.102
# Epoch: 0/5 Iteration: 440 Train loss: 0.110
# Epoch: 0/5 Iteration: 445 Train loss: 0.096
# Epoch: 0/5 Iteration: 450 Train loss: 0.096
# Val acc: 0.864
# Epoch: 0/5 Iteration: 455 Train loss: 0.087
# Epoch: 0/5 Iteration: 460 Train loss: 0.098
# Epoch: 0/5 Iteration: 465 Train loss: 0.089
# Epoch: 0/5 Iteration: 470 Train loss: 0.085
# Epoch: 0/5 Iteration: 475 Train loss: 0.096
# Val acc: 0.872
# Epoch: 0/5 Iteration: 480 Train loss: 0.085
# Epoch: 0/5 Iteration: 485 Train loss: 0.101
# Epoch: 0/5 Iteration: 490 Train loss: 0.087
# Epoch: 0/5 Iteration: 495 Train loss: 0.113
# Epoch: 0/5 Iteration: 500 Train loss: 0.080
# Val acc: 0.875
# Epoch: 0/5 Iteration: 505 Train loss: 0.105
# Epoch: 0/5 Iteration: 510 Train loss: 0.085
# Epoch: 0/5 Iteration: 515 Train loss: 0.102
# Epoch: 0/5 Iteration: 520 Train loss: 0.083
# Epoch: 0/5 Iteration: 525 Train loss: 0.092
# Val acc: 0.879
# Epoch: 0/5 Iteration: 530 Train loss: 0.077
# Epoch: 0/5 Iteration: 535 Train loss: 0.091
# Epoch: 0/5 Iteration: 540 Train loss: 0.093
# Epoch: 0/5 Iteration: 545 Train loss: 0.091
# Epoch: 0/5 Iteration: 550 Train loss: 0.096
# Val acc: 0.883
# Epoch: 0/5 Iteration: 555 Train loss: 0.082
# Epoch: 0/5 Iteration: 560 Train loss: 0.075
# Epoch: 0/5 Iteration: 565 Train loss: 0.095
# Epoch: 0/5 Iteration: 570 Train loss: 0.084
# Epoch: 0/5 Iteration: 575 Train loss: 0.093
# Val acc: 0.879
# Epoch: 0/5 Iteration: 580 Train loss: 0.084
# Epoch: 0/5 Iteration: 585 Train loss: 0.086
# Epoch: 0/5 Iteration: 590 Train loss: 0.080
# Epoch: 0/5 Iteration: 595 Train loss: 0.076
# Epoch: 0/5 Iteration: 600 Train loss: 0.087
# Val acc: 0.877
# Epoch: 0/5 Iteration: 605 Train loss: 0.110
# Epoch: 0/5 Iteration: 610 Train loss: 0.086
# Epoch: 0/5 Iteration: 615 Train loss: 0.092
# Epoch: 0/5 Iteration: 620 Train loss: 0.079
# Epoch: 0/5 Iteration: 625 Train loss: 0.082
# Val acc: 0.888
# Epoch: 0/5 Iteration: 630 Train loss: 0.080
# Epoch: 0/5 Iteration: 635 Train loss: 0.091
# Epoch: 0/5 Iteration: 640 Train loss: 0.071
# Epoch: 0/5 Iteration: 645 Train loss: 0.082
# Epoch: 0/5 Iteration: 650 Train loss: 0.080
# Val acc: 0.887
# Epoch: 0/5 Iteration: 655 Train loss: 0.091
# Epoch: 0/5 Iteration: 660 Train loss: 0.090
# Epoch: 0/5 Iteration: 665 Train loss: 0.097
# Epoch: 0/5 Iteration: 670 Train loss: 0.080
# Epoch: 0/5 Iteration: 675 Train loss: 0.079
# Val acc: 0.890
# Epoch: 0/5 Iteration: 680 Train loss: 0.061
# Epoch: 0/5 Iteration: 685 Train loss: 0.119
# Epoch: 0/5 Iteration: 690 Train loss: 0.084
# Epoch: 0/5 Iteration: 695 Train loss: 0.094
# Epoch: 0/5 Iteration: 700 Train loss: 0.087
# Val acc: 0.890
# Epoch: 0/5 Iteration: 705 Train loss: 0.064
# Epoch: 0/5 Iteration: 710 Train loss: 0.080
# Epoch: 0/5 Iteration: 715 Train loss: 0.081
# Epoch: 0/5 Iteration: 720 Train loss: 0.085
# Epoch: 0/5 Iteration: 725 Train loss: 0.060
# Val acc: 0.894
# Epoch: 0/5 Iteration: 730 Train loss: 0.080
# Epoch: 0/5 Iteration: 735 Train loss: 0.091
# Epoch: 0/5 Iteration: 740 Train loss: 0.077
# Epoch: 0/5 Iteration: 745 Train loss: 0.085
# Epoch: 0/5 Iteration: 750 Train loss: 0.086
# Val acc: 0.891
# Epoch: 0/5 Iteration: 755 Train loss: 0.080
# Epoch: 0/5 Iteration: 760 Train loss: 0.073
# Epoch: 0/5 Iteration: 765 Train loss: 0.067
# Epoch: 0/5 Iteration: 770 Train loss: 0.080
# Epoch: 0/5 Iteration: 775 Train loss: 0.070
# Val acc: 0.895
# Epoch: 0/5 Iteration: 780 Train loss: 0.074
# Epoch: 0/5 Iteration: 785 Train loss: 0.089
# Epoch: 0/5 Iteration: 790 Train loss: 0.068
# Epoch: 0/5 Iteration: 795 Train loss: 0.088
# Epoch: 0/5 Iteration: 800 Train loss: 0.067
# Val acc: 0.896
# Epoch: 0/5 Iteration: 805 Train loss: 0.080
# Epoch: 0/5 Iteration: 810 Train loss: 0.071
# Epoch: 0/5 Iteration: 815 Train loss: 0.082
# Epoch: 0/5 Iteration: 820 Train loss: 0.071
# Epoch: 0/5 Iteration: 825 Train loss: 0.074
# Val acc: 0.897
# Epoch: 0/5 Iteration: 830 Train loss: 0.060
# Epoch: 0/5 Iteration: 835 Train loss: 0.075
# Epoch: 0/5 Iteration: 840 Train loss: 0.071
# Epoch: 0/5 Iteration: 845 Train loss: 0.079
# Epoch: 0/5 Iteration: 850 Train loss: 0.086
# Val acc: 0.893
# Epoch: 0/5 Iteration: 855 Train loss: 0.080
# Epoch: 0/5 Iteration: 860 Train loss: 0.094
# Epoch: 0/5 Iteration: 865 Train loss: 0.077
# Epoch: 0/5 Iteration: 870 Train loss: 0.077
# Epoch: 0/5 Iteration: 875 Train loss: 0.076
# Val acc: 0.899
# Epoch: 0/5 Iteration: 880 Train loss: 0.064
# Epoch: 0/5 Iteration: 885 Train loss: 0.084
# Epoch: 0/5 Iteration: 890 Train loss: 0.073
# Epoch: 0/5 Iteration: 895 Train loss: 0.063
# Epoch: 0/5 Iteration: 900 Train loss: 0.079
# Val acc: 0.895
# Epoch: 0/5 Iteration: 905 Train loss: 0.075
# Epoch: 1/5 Iteration: 910 Train loss: 0.084
# Epoch: 1/5 Iteration: 915 Train loss: 0.075
# Epoch: 1/5 Iteration: 920 Train loss: 0.082
# Epoch: 1/5 Iteration: 925 Train loss: 0.080
# Val acc: 0.899
# Epoch: 1/5 Iteration: 930 Train loss: 0.060
# Epoch: 1/5 Iteration: 935 Train loss: 0.074
# Epoch: 1/5 Iteration: 940 Train loss: 0.073
# Epoch: 1/5 Iteration: 945 Train loss: 0.092
# Epoch: 1/5 Iteration: 950 Train loss: 0.084
# Val acc: 0.900
# Epoch: 1/5 Iteration: 955 Train loss: 0.055
# Epoch: 1/5 Iteration: 960 Train loss: 0.086
# Epoch: 1/5 Iteration: 965 Train loss: 0.070
# Epoch: 1/5 Iteration: 970 Train loss: 0.089
# Epoch: 1/5 Iteration: 975 Train loss: 0.074
# Val acc: 0.901
# Epoch: 1/5 Iteration: 980 Train loss: 0.083
# Epoch: 1/5 Iteration: 985 Train loss: 0.079
# Epoch: 1/5 Iteration: 990 Train loss: 0.089
# Epoch: 1/5 Iteration: 995 Train loss: 0.068
# Epoch: 1/5 Iteration: 1000 Train loss: 0.075
# Val acc: 0.890
# Epoch: 1/5 Iteration: 1005 Train loss: 0.054
# Epoch: 1/5 Iteration: 1010 Train loss: 0.063
# Epoch: 1/5 Iteration: 1015 Train loss: 0.070
# Epoch: 1/5 Iteration: 1020 Train loss: 0.072
# Epoch: 1/5 Iteration: 1025 Train loss: 0.075
# Val acc: 0.894
# Epoch: 1/5 Iteration: 1030 Train loss: 0.078
# Epoch: 1/5 Iteration: 1035 Train loss: 0.095
# Epoch: 1/5 Iteration: 1040 Train loss: 0.061
# Epoch: 1/5 Iteration: 1045 Train loss: 0.072
# Epoch: 1/5 Iteration: 1050 Train loss: 0.088
# Val acc: 0.903
# Epoch: 1/5 Iteration: 1055 Train loss: 0.067
# Epoch: 1/5 Iteration: 1060 Train loss: 0.049
# Epoch: 1/5 Iteration: 1065 Train loss: 0.085
# Epoch: 1/5 Iteration: 1070 Train loss: 0.070
# Epoch: 1/5 Iteration: 1075 Train loss: 0.076
# Val acc: 0.904
# Epoch: 1/5 Iteration: 1080 Train loss: 0.066
# Epoch: 1/5 Iteration: 1085 Train loss: 0.070
# Epoch: 1/5 Iteration: 1090 Train loss: 0.065
# Epoch: 1/5 Iteration: 1095 Train loss: 0.065
# Epoch: 1/5 Iteration: 1100 Train loss: 0.077
# Val acc: 0.905
# Epoch: 1/5 Iteration: 1105 Train loss: 0.072
# Epoch: 1/5 Iteration: 1110 Train loss: 0.063
# Epoch: 1/5 Iteration: 1115 Train loss: 0.080
# Epoch: 1/5 Iteration: 1120 Train loss: 0.071
# Epoch: 1/5 Iteration: 1125 Train loss: 0.071
# Val acc: 0.901
# Epoch: 1/5 Iteration: 1130 Train loss: 0.070
# Epoch: 1/5 Iteration: 1135 Train loss: 0.070
# Epoch: 1/5 Iteration: 1140 Train loss: 0.085
# Epoch: 1/5 Iteration: 1145 Train loss: 0.071
# Epoch: 1/5 Iteration: 1150 Train loss: 0.058
# Val acc: 0.903
# Epoch: 1/5 Iteration: 1155 Train loss: 0.066
# Epoch: 1/5 Iteration: 1160 Train loss: 0.076
# Epoch: 1/5 Iteration: 1165 Train loss: 0.069
# Epoch: 1/5 Iteration: 1170 Train loss: 0.061
# Epoch: 1/5 Iteration: 1175 Train loss: 0.067
# Val acc: 0.893
# Epoch: 1/5 Iteration: 1180 Train loss: 0.091
# Epoch: 1/5 Iteration: 1185 Train loss: 0.080
# Epoch: 1/5 Iteration: 1190 Train loss: 0.077
# Epoch: 1/5 Iteration: 1195 Train loss: 0.087
# Epoch: 1/5 Iteration: 1200 Train loss: 0.061
# Val acc: 0.904
# Epoch: 1/5 Iteration: 1205 Train loss: 0.067
# Epoch: 1/5 Iteration: 1210 Train loss: 0.081
# Epoch: 1/5 Iteration: 1215 Train loss: 0.067
# Epoch: 1/5 Iteration: 1220 Train loss: 0.071
# Epoch: 1/5 Iteration: 1225 Train loss: 0.074
# Val acc: 0.907
# Epoch: 1/5 Iteration: 1230 Train loss: 0.067
# Epoch: 1/5 Iteration: 1235 Train loss: 0.069
# Epoch: 1/5 Iteration: 1240 Train loss: 0.066
# Epoch: 1/5 Iteration: 1245 Train loss: 0.062
# Epoch: 1/5 Iteration: 1250 Train loss: 0.071
# Val acc: 0.906
# Epoch: 1/5 Iteration: 1255 Train loss: 0.054
# Epoch: 1/5 Iteration: 1260 Train loss: 0.065
# Epoch: 1/5 Iteration: 1265 Train loss: 0.081
# Epoch: 1/5 Iteration: 1270 Train loss: 0.058
# Epoch: 1/5 Iteration: 1275 Train loss: 0.053
# Val acc: 0.907
# Epoch: 1/5 Iteration: 1280 Train loss: 0.074
# Epoch: 1/5 Iteration: 1285 Train loss: 0.064
# Epoch: 1/5 Iteration: 1290 Train loss: 0.058
# Epoch: 1/5 Iteration: 1295 Train loss: 0.071
# Epoch: 1/5 Iteration: 1300 Train loss: 0.062
# Val acc: 0.902
# Epoch: 1/5 Iteration: 1305 Train loss: 0.062
# Epoch: 1/5 Iteration: 1310 Train loss: 0.069
# Epoch: 1/5 Iteration: 1315 Train loss: 0.075
# Epoch: 1/5 Iteration: 1320 Train loss: 0.077
# Epoch: 1/5 Iteration: 1325 Train loss: 0.076
# Val acc: 0.906
# Epoch: 1/5 Iteration: 1330 Train loss: 0.061
# Epoch: 1/5 Iteration: 1335 Train loss: 0.076
# Epoch: 1/5 Iteration: 1340 Train loss: 0.066
# Epoch: 1/5 Iteration: 1345 Train loss: 0.062
# Epoch: 1/5 Iteration: 1350 Train loss: 0.058
# Val acc: 0.907
# Epoch: 1/5 Iteration: 1355 Train loss: 0.070
# Epoch: 1/5 Iteration: 1360 Train loss: 0.067
# Epoch: 1/5 Iteration: 1365 Train loss: 0.067
# Epoch: 1/5 Iteration: 1370 Train loss: 0.066
# Epoch: 1/5 Iteration: 1375 Train loss: 0.062
# Val acc: 0.909
# Epoch: 1/5 Iteration: 1380 Train loss: 0.056
# Epoch: 1/5 Iteration: 1385 Train loss: 0.072
# Epoch: 1/5 Iteration: 1390 Train loss: 0.076
# Epoch: 1/5 Iteration: 1395 Train loss: 0.076
# Epoch: 1/5 Iteration: 1400 Train loss: 0.071
# Val acc: 0.904
# Epoch: 1/5 Iteration: 1405 Train loss: 0.060
# Epoch: 1/5 Iteration: 1410 Train loss: 0.057
# Epoch: 1/5 Iteration: 1415 Train loss: 0.056
# Epoch: 1/5 Iteration: 1420 Train loss: 0.077
# Epoch: 1/5 Iteration: 1425 Train loss: 0.059
# Val acc: 0.902
# Epoch: 1/5 Iteration: 1430 Train loss: 0.055
# Epoch: 1/5 Iteration: 1435 Train loss: 0.069
# Epoch: 1/5 Iteration: 1440 Train loss: 0.072
# Epoch: 1/5 Iteration: 1445 Train loss: 0.063
# Epoch: 1/5 Iteration: 1450 Train loss: 0.066
# Val acc: 0.910
# Epoch: 1/5 Iteration: 1455 Train loss: 0.067
# Epoch: 1/5 Iteration: 1460 Train loss: 0.059
# Epoch: 1/5 Iteration: 1465 Train loss: 0.053
# Epoch: 1/5 Iteration: 1470 Train loss: 0.055
# Epoch: 1/5 Iteration: 1475 Train loss: 0.061
# Val acc: 0.912
# Epoch: 1/5 Iteration: 1480 Train loss: 0.090
# Epoch: 1/5 Iteration: 1485 Train loss: 0.059
# Epoch: 1/5 Iteration: 1490 Train loss: 0.058
# Epoch: 1/5 Iteration: 1495 Train loss: 0.073
# Epoch: 1/5 Iteration: 1500 Train loss: 0.062
# Val acc: 0.911
# Epoch: 1/5 Iteration: 1505 Train loss: 0.063
# Epoch: 1/5 Iteration: 1510 Train loss: 0.062
# Epoch: 1/5 Iteration: 1515 Train loss: 0.064
# Epoch: 1/5 Iteration: 1520 Train loss: 0.060
# Epoch: 1/5 Iteration: 1525 Train loss: 0.078
# Val acc: 0.907
# Epoch: 1/5 Iteration: 1530 Train loss: 0.077
# Epoch: 1/5 Iteration: 1535 Train loss: 0.070
# Epoch: 1/5 Iteration: 1540 Train loss: 0.057
# Epoch: 1/5 Iteration: 1545 Train loss: 0.062
# Epoch: 1/5 Iteration: 1550 Train loss: 0.060
# Val acc: 0.911
# Epoch: 1/5 Iteration: 1555 Train loss: 0.053
# Epoch: 1/5 Iteration: 1560 Train loss: 0.078
# Epoch: 1/5 Iteration: 1565 Train loss: 0.063
# Epoch: 1/5 Iteration: 1570 Train loss: 0.074
# Epoch: 1/5 Iteration: 1575 Train loss: 0.067
# Val acc: 0.913
# Epoch: 1/5 Iteration: 1580 Train loss: 0.058
# Epoch: 1/5 Iteration: 1585 Train loss: 0.059
# Epoch: 1/5 Iteration: 1590 Train loss: 0.061
# Epoch: 1/5 Iteration: 1595 Train loss: 0.062
# Epoch: 1/5 Iteration: 1600 Train loss: 0.052
# Val acc: 0.906
# Epoch: 1/5 Iteration: 1605 Train loss: 0.058
# Epoch: 1/5 Iteration: 1610 Train loss: 0.063
# Epoch: 1/5 Iteration: 1615 Train loss: 0.062
# Epoch: 1/5 Iteration: 1620 Train loss: 0.043
# Epoch: 1/5 Iteration: 1625 Train loss: 0.056
# Val acc: 0.907
# Epoch: 1/5 Iteration: 1630 Train loss: 0.060
# Epoch: 1/5 Iteration: 1635 Train loss: 0.062
# Epoch: 1/5 Iteration: 1640 Train loss: 0.096
# Epoch: 1/5 Iteration: 1645 Train loss: 0.065
# Epoch: 1/5 Iteration: 1650 Train loss: 0.065
# Val acc: 0.912
# Epoch: 1/5 Iteration: 1655 Train loss: 0.063
# Epoch: 1/5 Iteration: 1660 Train loss: 0.072
# Epoch: 1/5 Iteration: 1665 Train loss: 0.052
# Epoch: 1/5 Iteration: 1670 Train loss: 0.062
# Epoch: 1/5 Iteration: 1675 Train loss: 0.065
# Val acc: 0.914
# Epoch: 1/5 Iteration: 1680 Train loss: 0.061
# Epoch: 1/5 Iteration: 1685 Train loss: 0.063
# Epoch: 1/5 Iteration: 1690 Train loss: 0.070
# Epoch: 1/5 Iteration: 1695 Train loss: 0.076
# Epoch: 1/5 Iteration: 1700 Train loss: 0.055
# Val acc: 0.913
# Epoch: 1/5 Iteration: 1705 Train loss: 0.068
# Epoch: 1/5 Iteration: 1710 Train loss: 0.066
# Epoch: 1/5 Iteration: 1715 Train loss: 0.068
# Epoch: 1/5 Iteration: 1720 Train loss: 0.062
# Epoch: 1/5 Iteration: 1725 Train loss: 0.050
# Val acc: 0.911
# Epoch: 1/5 Iteration: 1730 Train loss: 0.062
# Epoch: 1/5 Iteration: 1735 Train loss: 0.062
# Epoch: 1/5 Iteration: 1740 Train loss: 0.063
# Epoch: 1/5 Iteration: 1745 Train loss: 0.059
# Epoch: 1/5 Iteration: 1750 Train loss: 0.066
# Val acc: 0.916
# Epoch: 1/5 Iteration: 1755 Train loss: 0.053
# Epoch: 1/5 Iteration: 1760 Train loss: 0.047
# Epoch: 1/5 Iteration: 1765 Train loss: 0.052
# Epoch: 1/5 Iteration: 1770 Train loss: 0.060
# Epoch: 1/5 Iteration: 1775 Train loss: 0.065
# Val acc: 0.915
# Epoch: 1/5 Iteration: 1780 Train loss: 0.050
# Epoch: 1/5 Iteration: 1785 Train loss: 0.067
# Epoch: 1/5 Iteration: 1790 Train loss: 0.050
# Epoch: 1/5 Iteration: 1795 Train loss: 0.068
# Epoch: 1/5 Iteration: 1800 Train loss: 0.075
# Val acc: 0.914
# Epoch: 1/5 Iteration: 1805 Train loss: 0.077
# Epoch: 1/5 Iteration: 1810 Train loss: 0.079
# Epoch: 1/5 Iteration: 1815 Train loss: 0.061
# Epoch: 2/5 Iteration: 1820 Train loss: 0.050
# Epoch: 2/5 Iteration: 1825 Train loss: 0.068
# Val acc: 0.913
# Epoch: 2/5 Iteration: 1830 Train loss: 0.065
# Epoch: 2/5 Iteration: 1835 Train loss: 0.058
# Epoch: 2/5 Iteration: 1840 Train loss: 0.063
# Epoch: 2/5 Iteration: 1845 Train loss: 0.067
# Epoch: 2/5 Iteration: 1850 Train loss: 0.070
# Val acc: 0.912
# Epoch: 2/5 Iteration: 1855 Train loss: 0.064
# Epoch: 2/5 Iteration: 1860 Train loss: 0.057
# Epoch: 2/5 Iteration: 1865 Train loss: 0.066
# Epoch: 2/5 Iteration: 1870 Train loss: 0.075
# Epoch: 2/5 Iteration: 1875 Train loss: 0.063
# Val acc: 0.914
# Epoch: 2/5 Iteration: 1880 Train loss: 0.055
# Epoch: 2/5 Iteration: 1885 Train loss: 0.063
# Epoch: 2/5 Iteration: 1890 Train loss: 0.058
# Epoch: 2/5 Iteration: 1895 Train loss: 0.060
# Epoch: 2/5 Iteration: 1900 Train loss: 0.061
# Val acc: 0.915
# Epoch: 2/5 Iteration: 1905 Train loss: 0.060
# Epoch: 2/5 Iteration: 1910 Train loss: 0.040
# Epoch: 2/5 Iteration: 1915 Train loss: 0.066
# Epoch: 2/5 Iteration: 1920 Train loss: 0.066
# Epoch: 2/5 Iteration: 1925 Train loss: 0.052
# Val acc: 0.917
# Epoch: 2/5 Iteration: 1930 Train loss: 0.048
# Epoch: 2/5 Iteration: 1935 Train loss: 0.066
# Epoch: 2/5 Iteration: 1940 Train loss: 0.059
# Epoch: 2/5 Iteration: 1945 Train loss: 0.062
# Epoch: 2/5 Iteration: 1950 Train loss: 0.074
# Val acc: 0.915
# Epoch: 2/5 Iteration: 1955 Train loss: 0.054
# Epoch: 2/5 Iteration: 1960 Train loss: 0.077
# Epoch: 2/5 Iteration: 1965 Train loss: 0.055
# Epoch: 2/5 Iteration: 1970 Train loss: 0.049
# Epoch: 2/5 Iteration: 1975 Train loss: 0.057
# Val acc: 0.907
# Epoch: 2/5 Iteration: 1980 Train loss: 0.057
# Epoch: 2/5 Iteration: 1985 Train loss: 0.055
# Epoch: 2/5 Iteration: 1990 Train loss: 0.066
# Epoch: 2/5 Iteration: 1995 Train loss: 0.061
# Epoch: 2/5 Iteration: 2000 Train loss: 0.065
# Val acc: 0.914
# Epoch: 2/5 Iteration: 2005 Train loss: 0.061
# Epoch: 2/5 Iteration: 2010 Train loss: 0.058
# Epoch: 2/5 Iteration: 2015 Train loss: 0.068
# Epoch: 2/5 Iteration: 2020 Train loss: 0.061
# Epoch: 2/5 Iteration: 2025 Train loss: 0.066
# Val acc: 0.917
# Epoch: 2/5 Iteration: 2030 Train loss: 0.059
# Epoch: 2/5 Iteration: 2035 Train loss: 0.049
# Epoch: 2/5 Iteration: 2040 Train loss: 0.054
# Epoch: 2/5 Iteration: 2045 Train loss: 0.056
# Epoch: 2/5 Iteration: 2050 Train loss: 0.057
# Val acc: 0.914
# Epoch: 2/5 Iteration: 2055 Train loss: 0.051
# Epoch: 2/5 Iteration: 2060 Train loss: 0.050
# Epoch: 2/5 Iteration: 2065 Train loss: 0.045
# Epoch: 2/5 Iteration: 2070 Train loss: 0.066
# Epoch: 2/5 Iteration: 2075 Train loss: 0.063
# Val acc: 0.914
# Epoch: 2/5 Iteration: 2080 Train loss: 0.064
# Epoch: 2/5 Iteration: 2085 Train loss: 0.059
# Epoch: 2/5 Iteration: 2090 Train loss: 0.050
# Epoch: 2/5 Iteration: 2095 Train loss: 0.057
# Epoch: 2/5 Iteration: 2100 Train loss: 0.055
# Val acc: 0.918
# Epoch: 2/5 Iteration: 2105 Train loss: 0.065
# Epoch: 2/5 Iteration: 2110 Train loss: 0.040
# Epoch: 2/5 Iteration: 2115 Train loss: 0.047
# Epoch: 2/5 Iteration: 2120 Train loss: 0.059
# Epoch: 2/5 Iteration: 2125 Train loss: 0.057
# Val acc: 0.919
# Epoch: 2/5 Iteration: 2130 Train loss: 0.053
# Epoch: 2/5 Iteration: 2135 Train loss: 0.048
# Epoch: 2/5 Iteration: 2140 Train loss: 0.046
# Epoch: 2/5 Iteration: 2145 Train loss: 0.052
# Epoch: 2/5 Iteration: 2150 Train loss: 0.051
# Val acc: 0.919
# Epoch: 2/5 Iteration: 2155 Train loss: 0.061
# Epoch: 2/5 Iteration: 2160 Train loss: 0.053
# Epoch: 2/5 Iteration: 2165 Train loss: 0.057
# Epoch: 2/5 Iteration: 2170 Train loss: 0.057
# Epoch: 2/5 Iteration: 2175 Train loss: 0.056
# Val acc: 0.918
# Epoch: 2/5 Iteration: 2180 Train loss: 0.055
# Epoch: 2/5 Iteration: 2185 Train loss: 0.070
# Epoch: 2/5 Iteration: 2190 Train loss: 0.038
# Epoch: 2/5 Iteration: 2195 Train loss: 0.053
# Epoch: 2/5 Iteration: 2200 Train loss: 0.044
# Val acc: 0.914
# Epoch: 2/5 Iteration: 2205 Train loss: 0.056
# Epoch: 2/5 Iteration: 2210 Train loss: 0.056
# Epoch: 2/5 Iteration: 2215 Train loss: 0.055
# Epoch: 2/5 Iteration: 2220 Train loss: 0.057
# Epoch: 2/5 Iteration: 2225 Train loss: 0.050
# Val acc: 0.909
# Epoch: 2/5 Iteration: 2230 Train loss: 0.050
# Epoch: 2/5 Iteration: 2235 Train loss: 0.052
# Epoch: 2/5 Iteration: 2240 Train loss: 0.056
# Epoch: 2/5 Iteration: 2245 Train loss: 0.058
# Epoch: 2/5 Iteration: 2250 Train loss: 0.047
# Val acc: 0.919
# Epoch: 2/5 Iteration: 2255 Train loss: 0.047
# Epoch: 2/5 Iteration: 2260 Train loss: 0.047
# Epoch: 2/5 Iteration: 2265 Train loss: 0.049
# Epoch: 2/5 Iteration: 2270 Train loss: 0.050
# Epoch: 2/5 Iteration: 2275 Train loss: 0.051
# Val acc: 0.920
# Epoch: 2/5 Iteration: 2280 Train loss: 0.055
# Epoch: 2/5 Iteration: 2285 Train loss: 0.056
# Epoch: 2/5 Iteration: 2290 Train loss: 0.040
# Epoch: 2/5 Iteration: 2295 Train loss: 0.047
# Epoch: 2/5 Iteration: 2300 Train loss: 0.047
# Val acc: 0.920
# Epoch: 2/5 Iteration: 2305 Train loss: 0.042
# Epoch: 2/5 Iteration: 2310 Train loss: 0.049
# Epoch: 2/5 Iteration: 2315 Train loss: 0.045
# Epoch: 2/5 Iteration: 2320 Train loss: 0.055
# Epoch: 2/5 Iteration: 2325 Train loss: 0.058
# Val acc: 0.920
# Epoch: 2/5 Iteration: 2330 Train loss: 0.059
# Epoch: 2/5 Iteration: 2335 Train loss: 0.067
# Epoch: 2/5 Iteration: 2340 Train loss: 0.043
# Epoch: 2/5 Iteration: 2345 Train loss: 0.058
# Epoch: 2/5 Iteration: 2350 Train loss: 0.045
# Val acc: 0.917
# Epoch: 2/5 Iteration: 2355 Train loss: 0.046
# Epoch: 2/5 Iteration: 2360 Train loss: 0.049
# Epoch: 2/5 Iteration: 2365 Train loss: 0.052
# Epoch: 2/5 Iteration: 2370 Train loss: 0.051
# Epoch: 2/5 Iteration: 2375 Train loss: 0.063
# Val acc: 0.922
# Epoch: 2/5 Iteration: 2380 Train loss: 0.054
# Epoch: 2/5 Iteration: 2385 Train loss: 0.055
# Epoch: 2/5 Iteration: 2390 Train loss: 0.050
# Epoch: 2/5 Iteration: 2395 Train loss: 0.065
# Epoch: 2/5 Iteration: 2400 Train loss: 0.051
# Val acc: 0.922
# Epoch: 2/5 Iteration: 2405 Train loss: 0.040
# Epoch: 2/5 Iteration: 2410 Train loss: 0.044
# Epoch: 2/5 Iteration: 2415 Train loss: 0.062
# Epoch: 2/5 Iteration: 2420 Train loss: 0.068
# Epoch: 2/5 Iteration: 2425 Train loss: 0.059
# Val acc: 0.921
# Epoch: 2/5 Iteration: 2430 Train loss: 0.060
# Epoch: 2/5 Iteration: 2435 Train loss: 0.053
# Epoch: 2/5 Iteration: 2440 Train loss: 0.059
# Epoch: 2/5 Iteration: 2445 Train loss: 0.053
# Epoch: 2/5 Iteration: 2450 Train loss: 0.054
# Val acc: 0.917
# Epoch: 2/5 Iteration: 2455 Train loss: 0.038
# Epoch: 2/5 Iteration: 2460 Train loss: 0.060
# Epoch: 2/5 Iteration: 2465 Train loss: 0.061
# Epoch: 2/5 Iteration: 2470 Train loss: 0.053
# Epoch: 2/5 Iteration: 2475 Train loss: 0.055
# Val acc: 0.921
# Epoch: 2/5 Iteration: 2480 Train loss: 0.045
# Epoch: 2/5 Iteration: 2485 Train loss: 0.052
# Epoch: 2/5 Iteration: 2490 Train loss: 0.047
# Epoch: 2/5 Iteration: 2495 Train loss: 0.050
# Epoch: 2/5 Iteration: 2500 Train loss: 0.047
# Val acc: 0.922
# Epoch: 2/5 Iteration: 2505 Train loss: 0.055
# Epoch: 2/5 Iteration: 2510 Train loss: 0.045
# Epoch: 2/5 Iteration: 2515 Train loss: 0.049
# Epoch: 2/5 Iteration: 2520 Train loss: 0.049
# Epoch: 2/5 Iteration: 2525 Train loss: 0.051
# Val acc: 0.919
# Epoch: 2/5 Iteration: 2530 Train loss: 0.054
# Epoch: 2/5 Iteration: 2535 Train loss: 0.057
# Epoch: 2/5 Iteration: 2540 Train loss: 0.050
# Epoch: 2/5 Iteration: 2545 Train loss: 0.045
# Epoch: 2/5 Iteration: 2550 Train loss: 0.064
# Val acc: 0.922
# Epoch: 2/5 Iteration: 2555 Train loss: 0.044
# Epoch: 2/5 Iteration: 2560 Train loss: 0.047
# Epoch: 2/5 Iteration: 2565 Train loss: 0.050
# Epoch: 2/5 Iteration: 2570 Train loss: 0.053
# Epoch: 2/5 Iteration: 2575 Train loss: 0.044
# Val acc: 0.921
# Epoch: 2/5 Iteration: 2580 Train loss: 0.063
# Epoch: 2/5 Iteration: 2585 Train loss: 0.056
# Epoch: 2/5 Iteration: 2590 Train loss: 0.049
# Epoch: 2/5 Iteration: 2595 Train loss: 0.064
# Epoch: 2/5 Iteration: 2600 Train loss: 0.060
# Val acc: 0.922
# Epoch: 2/5 Iteration: 2605 Train loss: 0.055
# Epoch: 2/5 Iteration: 2610 Train loss: 0.050
# Epoch: 2/5 Iteration: 2615 Train loss: 0.059
# Epoch: 2/5 Iteration: 2620 Train loss: 0.052
# Epoch: 2/5 Iteration: 2625 Train loss: 0.048
# Val acc: 0.922
# Epoch: 2/5 Iteration: 2630 Train loss: 0.060
# Epoch: 2/5 Iteration: 2635 Train loss: 0.046
# Epoch: 2/5 Iteration: 2640 Train loss: 0.059
# Epoch: 2/5 Iteration: 2645 Train loss: 0.040
# Epoch: 2/5 Iteration: 2650 Train loss: 0.050
# Val acc: 0.919
# Epoch: 2/5 Iteration: 2655 Train loss: 0.047
# Epoch: 2/5 Iteration: 2660 Train loss: 0.044
# Epoch: 2/5 Iteration: 2665 Train loss: 0.056
# Epoch: 2/5 Iteration: 2670 Train loss: 0.056
# Epoch: 2/5 Iteration: 2675 Train loss: 0.039
# Val acc: 0.920
# Epoch: 2/5 Iteration: 2680 Train loss: 0.050
# Epoch: 2/5 Iteration: 2685 Train loss: 0.053
# Epoch: 2/5 Iteration: 2690 Train loss: 0.062
# Epoch: 2/5 Iteration: 2695 Train loss: 0.048
# Epoch: 2/5 Iteration: 2700 Train loss: 0.051
# Val acc: 0.918
# Epoch: 2/5 Iteration: 2705 Train loss: 0.049
# Epoch: 2/5 Iteration: 2710 Train loss: 0.046
# Epoch: 2/5 Iteration: 2715 Train loss: 0.053
# Epoch: 2/5 Iteration: 2720 Train loss: 0.047
# Epoch: 2/5 Iteration: 2725 Train loss: 0.046
# Val acc: 0.922
# Epoch: 3/5 Iteration: 2730 Train loss: 0.047
# Epoch: 3/5 Iteration: 2735 Train loss: 0.041
# Epoch: 3/5 Iteration: 2740 Train loss: 0.045
# Epoch: 3/5 Iteration: 2745 Train loss: 0.064
# Epoch: 3/5 Iteration: 2750 Train loss: 0.054
# Val acc: 0.922
# Epoch: 3/5 Iteration: 2755 Train loss: 0.057
# Epoch: 3/5 Iteration: 2760 Train loss: 0.057
# Epoch: 3/5 Iteration: 2765 Train loss: 0.059
# Epoch: 3/5 Iteration: 2770 Train loss: 0.061
# Epoch: 3/5 Iteration: 2775 Train loss: 0.061
# Val acc: 0.920
# Epoch: 3/5 Iteration: 2780 Train loss: 0.058
# Epoch: 3/5 Iteration: 2785 Train loss: 0.046
# Epoch: 3/5 Iteration: 2790 Train loss: 0.071
# Epoch: 3/5 Iteration: 2795 Train loss: 0.051
# Epoch: 3/5 Iteration: 2800 Train loss: 0.061
# Val acc: 0.924
# Epoch: 3/5 Iteration: 2805 Train loss: 0.049
# Epoch: 3/5 Iteration: 2810 Train loss: 0.058
# Epoch: 3/5 Iteration: 2815 Train loss: 0.043
# Epoch: 3/5 Iteration: 2820 Train loss: 0.044
# Epoch: 3/5 Iteration: 2825 Train loss: 0.050
# Val acc: 0.924
# Epoch: 3/5 Iteration: 2830 Train loss: 0.040
# Epoch: 3/5 Iteration: 2835 Train loss: 0.040
# Epoch: 3/5 Iteration: 2840 Train loss: 0.045
# Epoch: 3/5 Iteration: 2845 Train loss: 0.060
# Epoch: 3/5 Iteration: 2850 Train loss: 0.049
# Val acc: 0.919
# Epoch: 3/5 Iteration: 2855 Train loss: 0.055
# Epoch: 3/5 Iteration: 2860 Train loss: 0.057
# Epoch: 3/5 Iteration: 2865 Train loss: 0.060
# Epoch: 3/5 Iteration: 2870 Train loss: 0.038
# Epoch: 3/5 Iteration: 2875 Train loss: 0.049
# Val acc: 0.918
# Epoch: 3/5 Iteration: 2880 Train loss: 0.047
# Epoch: 3/5 Iteration: 2885 Train loss: 0.042
# Epoch: 3/5 Iteration: 2890 Train loss: 0.040
# Epoch: 3/5 Iteration: 2895 Train loss: 0.050
# Epoch: 3/5 Iteration: 2900 Train loss: 0.054
# Val acc: 0.923
# Epoch: 3/5 Iteration: 2905 Train loss: 0.041
# Epoch: 3/5 Iteration: 2910 Train loss: 0.044
# Epoch: 3/5 Iteration: 2915 Train loss: 0.053
# Epoch: 3/5 Iteration: 2920 Train loss: 0.045
# Epoch: 3/5 Iteration: 2925 Train loss: 0.060
# Val acc: 0.922
# Epoch: 3/5 Iteration: 2930 Train loss: 0.037
# Epoch: 3/5 Iteration: 2935 Train loss: 0.053
# Epoch: 3/5 Iteration: 2940 Train loss: 0.050
# Epoch: 3/5 Iteration: 2945 Train loss: 0.039
# Epoch: 3/5 Iteration: 2950 Train loss: 0.046
# Val acc: 0.922
# Epoch: 3/5 Iteration: 2955 Train loss: 0.050
# Epoch: 3/5 Iteration: 2960 Train loss: 0.037
# Epoch: 3/5 Iteration: 2965 Train loss: 0.031
# Epoch: 3/5 Iteration: 2970 Train loss: 0.050
# Epoch: 3/5 Iteration: 2975 Train loss: 0.052
# Val acc: 0.924
# Epoch: 3/5 Iteration: 2980 Train loss: 0.059
# Epoch: 3/5 Iteration: 2985 Train loss: 0.043
# Epoch: 3/5 Iteration: 2990 Train loss: 0.050
# Epoch: 3/5 Iteration: 2995 Train loss: 0.037
# Epoch: 3/5 Iteration: 3000 Train loss: 0.039
# Val acc: 0.922
# Epoch: 3/5 Iteration: 3005 Train loss: 0.050
# Epoch: 3/5 Iteration: 3010 Train loss: 0.039
# Epoch: 3/5 Iteration: 3015 Train loss: 0.057
# Epoch: 3/5 Iteration: 3020 Train loss: 0.050
# Epoch: 3/5 Iteration: 3025 Train loss: 0.049
# Val acc: 0.914
# Epoch: 3/5 Iteration: 3030 Train loss: 0.060
# Epoch: 3/5 Iteration: 3035 Train loss: 0.041
# Epoch: 3/5 Iteration: 3040 Train loss: 0.062
# Epoch: 3/5 Iteration: 3045 Train loss: 0.061
# Epoch: 3/5 Iteration: 3050 Train loss: 0.060
# Val acc: 0.924
# Epoch: 3/5 Iteration: 3055 Train loss: 0.041
# Epoch: 3/5 Iteration: 3060 Train loss: 0.033
# Epoch: 3/5 Iteration: 3065 Train loss: 0.043
# Epoch: 3/5 Iteration: 3070 Train loss: 0.072
# Epoch: 3/5 Iteration: 3075 Train loss: 0.060
# Val acc: 0.925
# Epoch: 3/5 Iteration: 3080 Train loss: 0.042
# Epoch: 3/5 Iteration: 3085 Train loss: 0.065
# Epoch: 3/5 Iteration: 3090 Train loss: 0.055
# Epoch: 3/5 Iteration: 3095 Train loss: 0.053
# Epoch: 3/5 Iteration: 3100 Train loss: 0.062
# Val acc: 0.916
# Epoch: 3/5 Iteration: 3105 Train loss: 0.055
# Epoch: 3/5 Iteration: 3110 Train loss: 0.047
# Epoch: 3/5 Iteration: 3115 Train loss: 0.039
# Epoch: 3/5 Iteration: 3120 Train loss: 0.039
# Epoch: 3/5 Iteration: 3125 Train loss: 0.040
# Val acc: 0.904
# Epoch: 3/5 Iteration: 3130 Train loss: 0.046
# Epoch: 3/5 Iteration: 3135 Train loss: 0.055
# Epoch: 3/5 Iteration: 3140 Train loss: 0.046
# Epoch: 3/5 Iteration: 3145 Train loss: 0.043
# Epoch: 3/5 Iteration: 3150 Train loss: 0.058
# Val acc: 0.923
# Epoch: 3/5 Iteration: 3155 Train loss: 0.052
# Epoch: 3/5 Iteration: 3160 Train loss: 0.053
# Epoch: 3/5 Iteration: 3165 Train loss: 0.046
# Epoch: 3/5 Iteration: 3170 Train loss: 0.054
# Epoch: 3/5 Iteration: 3175 Train loss: 0.036
# Val acc: 0.922
# Epoch: 3/5 Iteration: 3180 Train loss: 0.049
# Epoch: 3/5 Iteration: 3185 Train loss: 0.041
# Epoch: 3/5 Iteration: 3190 Train loss: 0.047
# Epoch: 3/5 Iteration: 3195 Train loss: 0.054
# Epoch: 3/5 Iteration: 3200 Train loss: 0.056
# Val acc: 0.923
# Epoch: 3/5 Iteration: 3205 Train loss: 0.041
# Epoch: 3/5 Iteration: 3210 Train loss: 0.045
# Epoch: 3/5 Iteration: 3215 Train loss: 0.062
# Epoch: 3/5 Iteration: 3220 Train loss: 0.054
# Epoch: 3/5 Iteration: 3225 Train loss: 0.044
# Val acc: 0.926
# Epoch: 3/5 Iteration: 3230 Train loss: 0.037
# Epoch: 3/5 Iteration: 3235 Train loss: 0.054
# Epoch: 3/5 Iteration: 3240 Train loss: 0.056
# Epoch: 3/5 Iteration: 3245 Train loss: 0.050
# Epoch: 3/5 Iteration: 3250 Train loss: 0.064
# Val acc: 0.926
# Epoch: 3/5 Iteration: 3255 Train loss: 0.034
# Epoch: 3/5 Iteration: 3260 Train loss: 0.040
# Epoch: 3/5 Iteration: 3265 Train loss: 0.046
# Epoch: 3/5 Iteration: 3270 Train loss: 0.042
# Epoch: 3/5 Iteration: 3275 Train loss: 0.044
# Val acc: 0.924
# Epoch: 3/5 Iteration: 3280 Train loss: 0.040
# Epoch: 3/5 Iteration: 3285 Train loss: 0.054
# Epoch: 3/5 Iteration: 3290 Train loss: 0.039
# Epoch: 3/5 Iteration: 3295 Train loss: 0.045
# Epoch: 3/5 Iteration: 3300 Train loss: 0.050
# Val acc: 0.925
# Epoch: 3/5 Iteration: 3305 Train loss: 0.044
# Epoch: 3/5 Iteration: 3310 Train loss: 0.038
# Epoch: 3/5 Iteration: 3315 Train loss: 0.039
# Epoch: 3/5 Iteration: 3320 Train loss: 0.044
# Epoch: 3/5 Iteration: 3325 Train loss: 0.042
# Val acc: 0.925
# Epoch: 3/5 Iteration: 3330 Train loss: 0.045
# Epoch: 3/5 Iteration: 3335 Train loss: 0.040
# Epoch: 3/5 Iteration: 3340 Train loss: 0.054
# Epoch: 3/5 Iteration: 3345 Train loss: 0.043
# Epoch: 3/5 Iteration: 3350 Train loss: 0.042
# Val acc: 0.918
# Epoch: 3/5 Iteration: 3355 Train loss: 0.035
# Epoch: 3/5 Iteration: 3360 Train loss: 0.047
# Epoch: 3/5 Iteration: 3365 Train loss: 0.049
# Epoch: 3/5 Iteration: 3370 Train loss: 0.054
# Epoch: 3/5 Iteration: 3375 Train loss: 0.055
# Val acc: 0.925
# Epoch: 3/5 Iteration: 3380 Train loss: 0.058
# Epoch: 3/5 Iteration: 3385 Train loss: 0.052
# Epoch: 3/5 Iteration: 3390 Train loss: 0.049
# Epoch: 3/5 Iteration: 3395 Train loss: 0.050
# Epoch: 3/5 Iteration: 3400 Train loss: 0.040
# Val acc: 0.927
# Epoch: 3/5 Iteration: 3405 Train loss: 0.061
# Epoch: 3/5 Iteration: 3410 Train loss: 0.045
# Epoch: 3/5 Iteration: 3415 Train loss: 0.056
# Epoch: 3/5 Iteration: 3420 Train loss: 0.053
# Epoch: 3/5 Iteration: 3425 Train loss: 0.045
# Val acc: 0.923
# Epoch: 3/5 Iteration: 3430 Train loss: 0.050
# Epoch: 3/5 Iteration: 3435 Train loss: 0.055
# Epoch: 3/5 Iteration: 3440 Train loss: 0.053
# Epoch: 3/5 Iteration: 3445 Train loss: 0.043
# Epoch: 3/5 Iteration: 3450 Train loss: 0.050
# Val acc: 0.924
# Epoch: 3/5 Iteration: 3455 Train loss: 0.046
# Epoch: 3/5 Iteration: 3460 Train loss: 0.049
# Epoch: 3/5 Iteration: 3465 Train loss: 0.044
# Epoch: 3/5 Iteration: 3470 Train loss: 0.046
# Epoch: 3/5 Iteration: 3475 Train loss: 0.037
# Val acc: 0.926
# Epoch: 3/5 Iteration: 3480 Train loss: 0.042
# Epoch: 3/5 Iteration: 3485 Train loss: 0.041
# Epoch: 3/5 Iteration: 3490 Train loss: 0.032
# Epoch: 3/5 Iteration: 3495 Train loss: 0.046
# Epoch: 3/5 Iteration: 3500 Train loss: 0.050
# Val acc: 0.927
# Epoch: 3/5 Iteration: 3505 Train loss: 0.050
# Epoch: 3/5 Iteration: 3510 Train loss: 0.047
# Epoch: 3/5 Iteration: 3515 Train loss: 0.047
# Epoch: 3/5 Iteration: 3520 Train loss: 0.045
# Epoch: 3/5 Iteration: 3525 Train loss: 0.057
# Val acc: 0.921
# Epoch: 3/5 Iteration: 3530 Train loss: 0.053
# Epoch: 3/5 Iteration: 3535 Train loss: 0.041
# Epoch: 3/5 Iteration: 3540 Train loss: 0.047
# Epoch: 3/5 Iteration: 3545 Train loss: 0.037
# Epoch: 3/5 Iteration: 3550 Train loss: 0.051
# Val acc: 0.925
# Epoch: 3/5 Iteration: 3555 Train loss: 0.052
# Epoch: 3/5 Iteration: 3560 Train loss: 0.046
# Epoch: 3/5 Iteration: 3565 Train loss: 0.037
# Epoch: 3/5 Iteration: 3570 Train loss: 0.036
# Epoch: 3/5 Iteration: 3575 Train loss: 0.062
# Val acc: 0.921
# Epoch: 3/5 Iteration: 3580 Train loss: 0.049
# Epoch: 3/5 Iteration: 3585 Train loss: 0.045
# Epoch: 3/5 Iteration: 3590 Train loss: 0.041
# Epoch: 3/5 Iteration: 3595 Train loss: 0.046
# Epoch: 3/5 Iteration: 3600 Train loss: 0.040
# Val acc: 0.925
# Epoch: 3/5 Iteration: 3605 Train loss: 0.047
# Epoch: 3/5 Iteration: 3610 Train loss: 0.038
# Epoch: 3/5 Iteration: 3615 Train loss: 0.037
# Epoch: 3/5 Iteration: 3620 Train loss: 0.048
# Epoch: 3/5 Iteration: 3625 Train loss: 0.061
# Val acc: 0.926
# Epoch: 3/5 Iteration: 3630 Train loss: 0.048
# Epoch: 3/5 Iteration: 3635 Train loss: 0.055
# Epoch: 4/5 Iteration: 3640 Train loss: 0.056
# Epoch: 4/5 Iteration: 3645 Train loss: 0.049
# Epoch: 4/5 Iteration: 3650 Train loss: 0.029
# Val acc: 0.928
# Epoch: 4/5 Iteration: 3655 Train loss: 0.031
# Epoch: 4/5 Iteration: 3660 Train loss: 0.044
# Epoch: 4/5 Iteration: 3665 Train loss: 0.036
# Epoch: 4/5 Iteration: 3670 Train loss: 0.051
# Epoch: 4/5 Iteration: 3675 Train loss: 0.041
# Val acc: 0.927
# Epoch: 4/5 Iteration: 3680 Train loss: 0.048
# Epoch: 4/5 Iteration: 3685 Train loss: 0.057
# Epoch: 4/5 Iteration: 3690 Train loss: 0.039
# Epoch: 4/5 Iteration: 3695 Train loss: 0.039
# Epoch: 4/5 Iteration: 3700 Train loss: 0.050
# Val acc: 0.926
# Epoch: 4/5 Iteration: 3705 Train loss: 0.044
# Epoch: 4/5 Iteration: 3710 Train loss: 0.050
# Epoch: 4/5 Iteration: 3715 Train loss: 0.046
# Epoch: 4/5 Iteration: 3720 Train loss: 0.056
# Epoch: 4/5 Iteration: 3725 Train loss: 0.043
# Val acc: 0.927
# Epoch: 4/5 Iteration: 3730 Train loss: 0.043
# Epoch: 4/5 Iteration: 3735 Train loss: 0.046
# Epoch: 4/5 Iteration: 3740 Train loss: 0.044
# Epoch: 4/5 Iteration: 3745 Train loss: 0.057
# Epoch: 4/5 Iteration: 3750 Train loss: 0.033
# Val acc: 0.924
# Epoch: 4/5 Iteration: 3755 Train loss: 0.042
# Epoch: 4/5 Iteration: 3760 Train loss: 0.036
# Epoch: 4/5 Iteration: 3765 Train loss: 0.034
# Epoch: 4/5 Iteration: 3770 Train loss: 0.033
# Epoch: 4/5 Iteration: 3775 Train loss: 0.062
# Val acc: 0.926
# Epoch: 4/5 Iteration: 3780 Train loss: 0.033
# Epoch: 4/5 Iteration: 3785 Train loss: 0.049
# Epoch: 4/5 Iteration: 3790 Train loss: 0.049
# Epoch: 4/5 Iteration: 3795 Train loss: 0.055
# Epoch: 4/5 Iteration: 3800 Train loss: 0.050
# Val acc: 0.922
# Epoch: 4/5 Iteration: 3805 Train loss: 0.037
# Epoch: 4/5 Iteration: 3810 Train loss: 0.048
# Epoch: 4/5 Iteration: 3815 Train loss: 0.032
# Epoch: 4/5 Iteration: 3820 Train loss: 0.044
# Epoch: 4/5 Iteration: 3825 Train loss: 0.042
# Val acc: 0.928
# Epoch: 4/5 Iteration: 3830 Train loss: 0.037
# Epoch: 4/5 Iteration: 3835 Train loss: 0.038
# Epoch: 4/5 Iteration: 3840 Train loss: 0.032
# Epoch: 4/5 Iteration: 3845 Train loss: 0.048
# Epoch: 4/5 Iteration: 3850 Train loss: 0.043
# Val acc: 0.928
# Epoch: 4/5 Iteration: 3855 Train loss: 0.047
# Epoch: 4/5 Iteration: 3860 Train loss: 0.026
# Epoch: 4/5 Iteration: 3865 Train loss: 0.037
# Epoch: 4/5 Iteration: 3870 Train loss: 0.047
# Epoch: 4/5 Iteration: 3875 Train loss: 0.042
# Val acc: 0.924
# Epoch: 4/5 Iteration: 3880 Train loss: 0.055
# Epoch: 4/5 Iteration: 3885 Train loss: 0.042
# Epoch: 4/5 Iteration: 3890 Train loss: 0.046
# Epoch: 4/5 Iteration: 3895 Train loss: 0.044
# Epoch: 4/5 Iteration: 3900 Train loss: 0.061
# Val acc: 0.912
# Epoch: 4/5 Iteration: 3905 Train loss: 0.039
# Epoch: 4/5 Iteration: 3910 Train loss: 0.053
# Epoch: 4/5 Iteration: 3915 Train loss: 0.050
# Epoch: 4/5 Iteration: 3920 Train loss: 0.037
# Epoch: 4/5 Iteration: 3925 Train loss: 0.031
# Val acc: 0.924
# Epoch: 4/5 Iteration: 3930 Train loss: 0.059
# Epoch: 4/5 Iteration: 3935 Train loss: 0.037
# Epoch: 4/5 Iteration: 3940 Train loss: 0.041
# Epoch: 4/5 Iteration: 3945 Train loss: 0.047
# Epoch: 4/5 Iteration: 3950 Train loss: 0.039
# Val acc: 0.928
# Epoch: 4/5 Iteration: 3955 Train loss: 0.046
# Epoch: 4/5 Iteration: 3960 Train loss: 0.052
# Epoch: 4/5 Iteration: 3965 Train loss: 0.052
# Epoch: 4/5 Iteration: 3970 Train loss: 0.040
# Epoch: 4/5 Iteration: 3975 Train loss: 0.037
# Val acc: 0.924
# Epoch: 4/5 Iteration: 3980 Train loss: 0.039
# Epoch: 4/5 Iteration: 3985 Train loss: 0.036
# Epoch: 4/5 Iteration: 3990 Train loss: 0.041
# Epoch: 4/5 Iteration: 3995 Train loss: 0.034
# Epoch: 4/5 Iteration: 4000 Train loss: 0.039
# Val acc: 0.926
# Epoch: 4/5 Iteration: 4005 Train loss: 0.046
# Epoch: 4/5 Iteration: 4010 Train loss: 0.034
# Epoch: 4/5 Iteration: 4015 Train loss: 0.036
# Epoch: 4/5 Iteration: 4020 Train loss: 0.044
# Epoch: 4/5 Iteration: 4025 Train loss: 0.036
# Val acc: 0.927
# Epoch: 4/5 Iteration: 4030 Train loss: 0.035
# Epoch: 4/5 Iteration: 4035 Train loss: 0.044
# Epoch: 4/5 Iteration: 4040 Train loss: 0.043
# Epoch: 4/5 Iteration: 4045 Train loss: 0.044
# Epoch: 4/5 Iteration: 4050 Train loss: 0.048
# Val acc: 0.926
# Epoch: 4/5 Iteration: 4055 Train loss: 0.043
# Epoch: 4/5 Iteration: 4060 Train loss: 0.039
# Epoch: 4/5 Iteration: 4065 Train loss: 0.060
# Epoch: 4/5 Iteration: 4070 Train loss: 0.051
# Epoch: 4/5 Iteration: 4075 Train loss: 0.034
# Val acc: 0.924
# Epoch: 4/5 Iteration: 4080 Train loss: 0.050
# Epoch: 4/5 Iteration: 4085 Train loss: 0.052
# Epoch: 4/5 Iteration: 4090 Train loss: 0.037
# Epoch: 4/5 Iteration: 4095 Train loss: 0.054
# Epoch: 4/5 Iteration: 4100 Train loss: 0.031
# Val acc: 0.927
# Epoch: 4/5 Iteration: 4105 Train loss: 0.041
# Epoch: 4/5 Iteration: 4110 Train loss: 0.041
# Epoch: 4/5 Iteration: 4115 Train loss: 0.036
# Epoch: 4/5 Iteration: 4120 Train loss: 0.033
# Epoch: 4/5 Iteration: 4125 Train loss: 0.059
# Val acc: 0.924
# Epoch: 4/5 Iteration: 4130 Train loss: 0.048
# Epoch: 4/5 Iteration: 4135 Train loss: 0.033
# Epoch: 4/5 Iteration: 4140 Train loss: 0.037
# Epoch: 4/5 Iteration: 4145 Train loss: 0.043
# Epoch: 4/5 Iteration: 4150 Train loss: 0.042
# Val acc: 0.928
# Epoch: 4/5 Iteration: 4155 Train loss: 0.040
# Epoch: 4/5 Iteration: 4160 Train loss: 0.033
# Epoch: 4/5 Iteration: 4165 Train loss: 0.031
# Epoch: 4/5 Iteration: 4170 Train loss: 0.043
# Epoch: 4/5 Iteration: 4175 Train loss: 0.046
# Val acc: 0.927
# Epoch: 4/5 Iteration: 4180 Train loss: 0.036
# Epoch: 4/5 Iteration: 4185 Train loss: 0.044
# Epoch: 4/5 Iteration: 4190 Train loss: 0.045
# Epoch: 4/5 Iteration: 4195 Train loss: 0.049
# Epoch: 4/5 Iteration: 4200 Train loss: 0.037
# Val acc: 0.925
# Epoch: 4/5 Iteration: 4205 Train loss: 0.042
# Epoch: 4/5 Iteration: 4210 Train loss: 0.041
# Epoch: 4/5 Iteration: 4215 Train loss: 0.054
# Epoch: 4/5 Iteration: 4220 Train loss: 0.035
# Epoch: 4/5 Iteration: 4225 Train loss: 0.037
# Val acc: 0.927
# Epoch: 4/5 Iteration: 4230 Train loss: 0.041
# Epoch: 4/5 Iteration: 4235 Train loss: 0.038
# Epoch: 4/5 Iteration: 4240 Train loss: 0.052
# Epoch: 4/5 Iteration: 4245 Train loss: 0.030
# Epoch: 4/5 Iteration: 4250 Train loss: 0.034
# Val acc: 0.930
# Epoch: 4/5 Iteration: 4255 Train loss: 0.036
# Epoch: 4/5 Iteration: 4260 Train loss: 0.045
# Epoch: 4/5 Iteration: 4265 Train loss: 0.066
# Epoch: 4/5 Iteration: 4270 Train loss: 0.045
# Epoch: 4/5 Iteration: 4275 Train loss: 0.047
# Val acc: 0.926
# Epoch: 4/5 Iteration: 4280 Train loss: 0.043
# Epoch: 4/5 Iteration: 4285 Train loss: 0.039
# Epoch: 4/5 Iteration: 4290 Train loss: 0.036
# Epoch: 4/5 Iteration: 4295 Train loss: 0.053
# Epoch: 4/5 Iteration: 4300 Train loss: 0.052
# Val acc: 0.922
# Epoch: 4/5 Iteration: 4305 Train loss: 0.047
# Epoch: 4/5 Iteration: 4310 Train loss: 0.046
# Epoch: 4/5 Iteration: 4315 Train loss: 0.039
# Epoch: 4/5 Iteration: 4320 Train loss: 0.060
# Epoch: 4/5 Iteration: 4325 Train loss: 0.039
# Val acc: 0.924
# Epoch: 4/5 Iteration: 4330 Train loss: 0.036
# Epoch: 4/5 Iteration: 4335 Train loss: 0.025
# Epoch: 4/5 Iteration: 4340 Train loss: 0.043
# Epoch: 4/5 Iteration: 4345 Train loss: 0.044
# Epoch: 4/5 Iteration: 4350 Train loss: 0.037
# Val acc: 0.926
# Epoch: 4/5 Iteration: 4355 Train loss: 0.048
# Epoch: 4/5 Iteration: 4360 Train loss: 0.034
# Epoch: 4/5 Iteration: 4365 Train loss: 0.051
# Epoch: 4/5 Iteration: 4370 Train loss: 0.031
# Epoch: 4/5 Iteration: 4375 Train loss: 0.044
# Val acc: 0.929
# Epoch: 4/5 Iteration: 4380 Train loss: 0.043
# Epoch: 4/5 Iteration: 4385 Train loss: 0.045
# Epoch: 4/5 Iteration: 4390 Train loss: 0.045
# Epoch: 4/5 Iteration: 4395 Train loss: 0.048
# Epoch: 4/5 Iteration: 4400 Train loss: 0.039
# Val acc: 0.927
# Epoch: 4/5 Iteration: 4405 Train loss: 0.051
# Epoch: 4/5 Iteration: 4410 Train loss: 0.043
# Epoch: 4/5 Iteration: 4415 Train loss: 0.050
# Epoch: 4/5 Iteration: 4420 Train loss: 0.036
# Epoch: 4/5 Iteration: 4425 Train loss: 0.030
# Val acc: 0.929
# Epoch: 4/5 Iteration: 4430 Train loss: 0.030
# Epoch: 4/5 Iteration: 4435 Train loss: 0.043
# Epoch: 4/5 Iteration: 4440 Train loss: 0.024
# Epoch: 4/5 Iteration: 4445 Train loss: 0.044
# Epoch: 4/5 Iteration: 4450 Train loss: 0.038
# Val acc: 0.917
# Epoch: 4/5 Iteration: 4455 Train loss: 0.035
# Epoch: 4/5 Iteration: 4460 Train loss: 0.049
# Epoch: 4/5 Iteration: 4465 Train loss: 0.058
# Epoch: 4/5 Iteration: 4470 Train loss: 0.039
# Epoch: 4/5 Iteration: 4475 Train loss: 0.037
# Val acc: 0.924
# Epoch: 4/5 Iteration: 4480 Train loss: 0.050
# Epoch: 4/5 Iteration: 4485 Train loss: 0.042
# Epoch: 4/5 Iteration: 4490 Train loss: 0.031
# Epoch: 4/5 Iteration: 4495 Train loss: 0.044
# Epoch: 4/5 Iteration: 4500 Train loss: 0.043
# Val acc: 0.927
# Epoch: 4/5 Iteration: 4505 Train loss: 0.038
# Epoch: 4/5 Iteration: 4510 Train loss: 0.042
# Epoch: 4/5 Iteration: 4515 Train loss: 0.034
# Epoch: 4/5 Iteration: 4520 Train loss: 0.037
# Epoch: 4/5 Iteration: 4525 Train loss: 0.038
# Val acc: 0.927
# Epoch: 4/5 Iteration: 4530 Train loss: 0.055
# Epoch: 4/5 Iteration: 4535 Train loss: 0.040
# Epoch: 4/5 Iteration: 4540 Train loss: 0.058
# Epoch: 4/5 Iteration: 4545 Train loss: 0.039

# %%
tf.train.get_checkpoint_state('output/checkpoints')
# Out:
# model_checkpoint_path: "output/checkpoints/sentiment.ckpt"
# all_model_checkpoint_paths: "output/checkpoints/sentiment.ckpt"

# %% [markdown]
# ## Model Evaluation and Validation

# %% [markdown]
# The best way to see if our model is able to generalize is to test our model on the untouched testing set.

# %%
test_acc = []
test_pred = []
test_label = []
    
with tf.Session() as sess:
    saver = tf.train.Saver()
    saver.restore(sess, "output/checkpoints/sentiment.ckpt")
    test_state = sess.run(model.cell.zero_state(batch_size, tf.float32))
    
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {model.inputs_: x,
                model.labels_: y[:, None],
                model.keep_prob: 1,
                model.initial_state: test_state}
        batch_pred, batch_acc, test_state = sess.run([model.predictions,model.accuracy, model.final_state], feed_dict=feed)
        test_acc.append(batch_acc)
        test_pred = np.append(test_pred,batch_pred)
        test_label = np.append(test_label,y)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))

# %% [markdown]
#  In order to measure the performance of the binary classifier, we can plot the [ROC curve](https://en.wikipedia.org/wiki/Receiver_operating_characteristic). The ROC curve consists of plotting the true positive rate against the false positive rate. The best scenario is when the curve matches the left corner. This would mean that we are able to achieve 100% sensitivity (no false negatives) and 100% specificity (no false positives).

# %%
fpr, tpr, _ = roc_curve(test_label, test_pred)
roc_auc = auc(fpr, tpr)

# %%
plt.plot(fpr, tpr, label='AUC %0.2f'%(roc_auc))
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.title("Receiver Operating Characteristics Curve")
plt.show()
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# We can observe that the area under the curve (AUC) is equal to 0.96. Knowing that the maximum AUC score is equal to 1, we can conclude that our model does a pretty good job at making accurate predictions on unseen reviews. Moreover our model seems to be very balanced in terms of false positive rate vs false negative rate.

# %% [markdown]
# The other important metric is the F1 score, because it also takes into consideration, precision and recall. In our original dataset 78% of the reviews were positive. If we would use a naive algorithm and predict that all the reviews are positive, our accuracy would be 78%. This is why we should use the F1 score in order to measure the performance of our RNN.

# %%
print(classification_report(test_label, list(map(lambda x: round(x), test_pred))))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.90      0.73      0.81     12363
#         1.0       0.93      0.98      0.95     44137
#
# avg / total       0.92      0.92      0.92     56500

# %% [markdown]
# The final F1 score is equal to 0.92. The precision and recall are also equal to 0.92. It means once again that our model has a good balance between sensitivity and specificity. There is room for improvement but our RNN model has learned to distinguish negative fine food reviews from positive reviews.

# %% [markdown]
# ## Conclusion
#
# ### Reflection
#
# With this project, we were able to demonstrate that we can use RNN to predict sentiments. Once again, the strength of the RNN is that it's able to take into consideration the entire sequence of words, which help the model find nuances.
# The main challenge of using a deep learning approach is that it's very expensive in terms of computing and time. To train this network we had to use GPUs provided by the platform [FloydHub](https://www.floydhub.com). Even with GPUs, it takes at least 1.5 hours to train our model. It was definitely a challenge to build our model and tune the hyperparameters correctly .
#
# ### Improvement
#
# Deep Learning techniques tend to outperform every other algorithm when we get access to lots of data. So if we could train our model on a larger dataset, the model should definitely improve. With RNN, the model creates it's own representation of the sentence. The reviews contain vocabulary specific to the food product. If we had mode data, our model should be able to identify the specific characteristics that make a good product.
# In order to improve this model, we should also investigate if we could include the product name/product type. If we had this information maybe our RNN would be able to more easily identify the important characteristics for each product.
#
#
# -----------
#
# ### Resources
#
# https://www.udacity.com/course/deep-learning-nanodegree-foundation--nd101
#
# https://www.tensorflow.org/tutorials/word2vec
